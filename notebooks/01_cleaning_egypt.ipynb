# %% [markdown]
# ### Import required libraries
# - Import `clean_data` module from `scripts`.
# - Import `sqlite3` for database interaction.
# - Import `warnings` and disable warnings.
# - Import `pandas` for data manipulation.

# %%
from scripts.clean_data import *
import sqlite3
import warnings
import pandas as pd

warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load and preview data
# - Load CSV file `egypt_raw.csv` from `../data/raw/` into DataFrame.
# - Display first 5 rows of the DataFrame.

# %%
df_egypt = pd.read_csv('../data/raw/egypt_raw.csv')
df_egypt.head()
# Out:
#    Unnamed: 0                                               link  \
# 0           0  https://www.bayt.com/ar/egypt/jobs/%D9%81%D9%8...
# 1           1  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%A...
# 2           2  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 3           3  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 4           4  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
#
#                           title      date           salary  \
# 0   فنى صيانة معدات (ميكانيكا )     اليوم  $1,500 - $2,000
# 1  متخصص فى مجال السوشيال ميديا  في الامس              NaN
# 2                   موظف مبيعات  في الامس              NaN
# 3                   موظف مبيعات  في الامس              NaN
# 4                  مندوب مبيعات  في الامس        $0 - $500
#
#                                 career_level                         location  \
# 0                                  دوام كامل      العامرية · الإسكندرية · مصر
# 1  دوام جزئي · الحد الأدنى 3 سنوات من الخبرة                    القاهرة · مصر
# 2            دوام كامل · 1-3 سنوات من الخبرة  القاهرة الجديدة · القاهرة · مصر
# 3            دوام كامل · 1-3 سنوات من الخبرة  القاهرة الجديدة · القاهرة · مصر
# 4                                  دوام كامل                 منية النصر · مصر
#
#          num_of_vacancies                                           industry  \
# 0                     NaN              10-49 موظف · إنتاج الأغذية والمشروبات
# 1  الوظائف المتاحة عدد 10  10-49 موظف · الإنترنت والتجارة الإلكترونية - أ...
# 2                     NaN                        10-49 موظف · وكلاء السيارات
# 3                     NaN  10-49 موظف · صيانة السيارات وقطع الغيار وخدمات...
# 4  الوظائف المتاحة عدد 20               10-49 موظف · البيع بالتجزئة وبالجملة
#
#                                          description  ... remote  \
# 0  مطلوب فنى صيانة ميكانيكا معدات - لمصنع مخبوزات...  ...    NaN
# 1  متخصص فى مجال السوشيال ميديا ( الفيس بوك - الا...  ...   هجين
# 2  الحفاظ على سجلات المبيعات والتسليم ، وكذلك تحق...  ...    NaN
# 3  الحفاظ على سجلات المبيعات والتسليم ، وكذلك تحق...  ...    NaN
# 4  مندوب مبيعات سجائر الكتروني في محيط القاهرة وا...  ...    NaN
#
#                       num_of_exp residence_area nationality   sex  \
# 0                            NaN            NaN         NaN   NaN
# 1                 الحد الأدنى: 3            مصر         مصر   ذكر
# 2  الحد الأدنى: 1 الحد الأقصى: 3            NaN         مصر  أنثى
# 3  الحد الأدنى: 1 الحد الأقصى: 3            NaN         مصر  أنثى
# 4                            NaN            NaN         NaN   NaN
#
#            qualification                              age specialization  \
# 0                    NaN                              NaN            NaN
# 1  بكالوريوس/ دبلوم عالي  الحد الأدنى: 25 الحد الأقصى: 50           بدون
# 2                    NaN  الحد الأدنى: 22 الحد الأقصى: 28            NaN
# 3                    NaN  الحد الأدنى: 22 الحد الأقصى: 28            NaN
# 4                    NaN                              NaN            NaN
#
#   experience                            company_name
# 0        NaN                   Alexandrina for trade
# 1        NaN  المجموعة الدولية لحلول الملكية الفكرية
# 2        NaN                              awija auto
# 3        NaN                              awija auto
# 4        NaN                 Almanna Import & Export
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Split location and career_level columns
# - Split `location` column by separator `·`, keep index 1 as `city`.
# - Split `career_level` column by separator `·`, keep indexes 0, 1, 2 as `type`, `exp`, and `no_exp`.
# - Further process `career_level` column using `split_career_level` function.

# %%
split_column(df_egypt, 'location', [1], '·', ['city'], reverse=True)
split_career_level(df_egypt)
df_egypt.head(15)
# Out:
#     Unnamed: 0                                               link  \
# 0            0  https://www.bayt.com/ar/egypt/jobs/%D9%81%D9%8...
# 1            1  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%A...
# 2            2  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 3            3  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 4            4  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 5            5  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%A...
# 6            6  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 7            7  https://www.bayt.com/ar/egypt/jobs/%D8%A7%D9%8...
# 8            8  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%B...
# 9            9  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%A...
# 10          10  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 11          11  https://www.bayt.com/ar/egypt/jobs/%D8%B3%D9%8...
# 12          12  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%B...
# 13          13  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 14          14  https://www.bayt.com/ar/egypt/jobs/%D8%B9%D8%B...
#
#                            title        date           salary  \
# 0    فنى صيانة معدات (ميكانيكا )       اليوم  $1,500 - $2,000
# 1   متخصص فى مجال السوشيال ميديا    في الامس              NaN
# 2                    موظف مبيعات    في الامس              NaN
# 3                    موظف مبيعات    في الامس              NaN
# 4                   مندوب مبيعات    في الامس        $0 - $500
# 5     مدير انتاج للعمل بالسعودية   قبل يومين              NaN
# 6                   مندوب مبيعات   قبل يومين              NaN
# 7                     امين مخازن  قبل 3 أيام              NaN
# 8        مسئول التسويق والمبيعات  قبل 5 أيام              NaN
# 9                    مدير مبيعات  قبل 5 أيام              NaN
# 10                  مندوب مبيعات  قبل 6 أيام              NaN
# 11               سكرتيرة تنفيذية  قبل 6 أيام              NaN
# 12  مشرف انتاج من الاسكندرية فقط  قبل 6 أيام              NaN
# 13                مهندس مكتب فني  قبل 7 أيام              NaN
# 14                      عضو فريق  قبل 9 أيام              NaN
#
#                                       career_level  \
# 0                                        دوام كامل
# 1        دوام جزئي · الحد الأدنى 3 سنوات من الخبرة
# 2                  دوام كامل · 1-3 سنوات من الخبرة
# 3                  دوام كامل · 1-3 سنوات من الخبرة
# 4                                        دوام كامل
# 5                                        دوام كامل
# 6   دوام كامل · مبتدئ الخبرة · 0-1 سنوات من الخبرة
# 7   دوام كامل · متوسط الخبرة · 1-2 سنوات من الخبرة
# 8                                        دوام كامل
# 9                                        دوام كامل
# 10  دوام كامل · مبتدئ الخبرة · 0-5 سنوات من الخبرة
# 11                               دوام كامل · إدارة
# 12                                       دوام كامل
# 13                                       دوام كامل
# 14                                       دوام كامل
#
#                            location        num_of_vacancies  \
# 0       العامرية · الإسكندرية · مصر                     NaN
# 1                     القاهرة · مصر  الوظائف المتاحة عدد 10
# 2   القاهرة الجديدة · القاهرة · مصر                     NaN
# 3   القاهرة الجديدة · القاهرة · مصر                     NaN
# 4                  منية النصر · مصر  الوظائف المتاحة عدد 20
# 5         هليوبوليس · القاهرة · مصر                     NaN
# 6                   شرم الشيخ · مصر   الوظائف المتاحة عدد 3
# 7                   شرم الشيخ · مصر   الوظائف المتاحة عدد 2
# 8                     القاهرة · مصر                     NaN
# 9                               مصر                     NaN
# 10                      قليوب · مصر   الوظائف المتاحة عدد 6
# 11        مدينة نصر · القاهرة · مصر                     NaN
# 12      العامرية · الإسكندرية · مصر                     NaN
# 13         6 أكتوبر · القاهرة · مصر                     NaN
# 14                              مصر  الوظائف المتاحة عدد 39
#
#                                              industry  \
# 0               10-49 موظف · إنتاج الأغذية والمشروبات
# 1   10-49 موظف · الإنترنت والتجارة الإلكترونية - أ...
# 2                         10-49 موظف · وكلاء السيارات
# 3   10-49 موظف · صيانة السيارات وقطع الغيار وخدمات...
# 4                10-49 موظف · البيع بالتجزئة وبالجملة
# 5                         10-49 موظف · وكالات التوظيف
# 6                                50-99 موظف · التجارة
# 7                                50-99 موظف · التجارة
# 8                    1-9 موظف · التسويق - أبحاث السوق
# 9                                  1-9 موظف · التسويق
# 10                     50-99 موظف · المستشفيات الطبية
# 11                         1-9 موظف · البناء والتشييد
# 12              10-49 موظف · إنتاج الأغذية والمشروبات
# 13               10-49 موظف · توليد الطاقة الكهربائية
# 14           500 موظف أو أكثر · المطاعم وخدمات الطعام
#
#                                           description  ...   sex  \
# 0   مطلوب فنى صيانة ميكانيكا معدات - لمصنع مخبوزات...  ...   NaN
# 1   متخصص فى مجال السوشيال ميديا ( الفيس بوك - الا...  ...   ذكر
# 2   الحفاظ على سجلات المبيعات والتسليم ، وكذلك تحق...  ...  أنثى
# 3   الحفاظ على سجلات المبيعات والتسليم ، وكذلك تحق...  ...  أنثى
# 4   مندوب مبيعات سجائر الكتروني في محيط القاهرة وا...  ...   NaN
# 5   إدارة وتنظيم عمليات الإنتاج اليومية لضمان تحقي...  ...   NaN
# 6   المسمي الوظيفي : مندوب مبيعات المدير المباشر و...  ...   ذكر
# 7   المسمي الوظيفي : امين مخازنالمدير المباشر : مد...  ...   ذكر
# 8   إعلان وظيفي: مسئول التسويق والمبيعاتشركة أنظمة...  ...   NaN
# 9   فرصة عمل في Vixilia Agency – مدير مبيعات (Sale...  ...   NaN
# 10  المناديب المطلوبة مناطق ( القاهرة - الجيزة - ا...  ...   NaN
# 11  المهام والمسؤوليات:• تنظيم جدول المدير التنفيذ...  ...   NaN
# 12  إدارة الإنتاج: تنظيم وتخطيط عمليات الإنتاج لضم...  ...   NaN
# 13  مهندس مكتب فني تصميمات مصنع تشكيل معادن تصنيع ...  ...   NaN
# 14  شخص ودود، مرن، ومستعد للتعاون والعمل مع أعضاء ...  ...   NaN
#
#                     qualification                              age  \
# 0                             NaN                              NaN
# 1           بكالوريوس/ دبلوم عالي  الحد الأدنى: 25 الحد الأقصى: 50
# 2                             NaN  الحد الأدنى: 22 الحد الأقصى: 28
# 3                             NaN  الحد الأدنى: 22 الحد الأقصى: 28
# 4                             NaN                              NaN
# 5                             NaN                              NaN
# 6           بكالوريوس/ دبلوم عالي  الحد الأدنى: 25 الحد الأقصى: 31
# 7           بكالوريوس/ دبلوم عالي  الحد الأدنى: 25 الحد الأقصى: 31
# 8                             NaN                              NaN
# 9                             NaN                              NaN
# 10          بكالوريوس/ دبلوم عالي  الحد الأدنى: 22 الحد الأقصى: 40
# 11                            NaN                              NaN
# 12                            NaN                              NaN
# 13                            NaN                              NaN
# 14  الثانوية العامة أو ما يعادلها  الحد الأدنى: 18 الحد الأقصى: 35
#
#    specialization    experience                              company_name  \
# 0             NaN           NaN                     Alexandrina for trade
# 1            بدون           NaN    المجموعة الدولية لحلول الملكية الفكرية
# 2             NaN           NaN                                awija auto
# 3             NaN           NaN                                awija auto
# 4             NaN           NaN                   Almanna Import & Export
# 5             NaN           NaN  شركة البدوي للتوظيف/ Albadwy Recruitment
# 6        المبيعات  مبتدئ الخبرة                           sittin egy food
# 7           مخازن  متوسط الخبرة                           sittin egy food
# 8             NaN           NaN            الشربيني لأنظمة البناء الداخلي
# 9             NaN           NaN                             وكالة فيكسليا
# 10       المبيعات  مبتدئ الخبرة                       Egyptian Italian co
# 11            NaN         إدارة            الشربيني لأنظمة البناء الداخلي
# 12            NaN           NaN                     Alexandrina for trade
# 13            NaN           NaN                           Sun Energy Tech
# 14            NaN           NaN                           مطاعم واحد مشوى
#
#           city       type           exp                         no_exp
# 0   الإسكندرية  دوام كامل       Unknown                        Unknown
# 1      القاهرة  دوام جزئي       Unknown  الحد الأدنى 3 سنوات من الخبرة
# 2      القاهرة  دوام كامل       Unknown            1-3 سنوات من الخبرة
# 3      القاهرة  دوام كامل       Unknown            1-3 سنوات من الخبرة
# 4   منية النصر  دوام كامل       Unknown                        Unknown
# 5      القاهرة  دوام كامل       Unknown                        Unknown
# 6    شرم الشيخ  دوام كامل  مبتدئ الخبرة            0-1 سنوات من الخبرة
# 7    شرم الشيخ  دوام كامل  متوسط الخبرة            1-2 سنوات من الخبرة
# 8      القاهرة  دوام كامل       Unknown                        Unknown
# 9      Unknown  دوام كامل       Unknown                        Unknown
# 10       قليوب  دوام كامل  مبتدئ الخبرة            0-5 سنوات من الخبرة
# 11     القاهرة  دوام كامل         إدارة                        Unknown
# 12  الإسكندرية  دوام كامل       Unknown                        Unknown
# 13     القاهرة  دوام كامل       Unknown                        Unknown
# 14     Unknown  دوام كامل       Unknown                        Unknown
#
# [15 rows x 25 columns]

# %% [markdown]
# ### Clean and combine experience columns
# - Replace 'Unknown' values in `exp` column with `NaN`.
# - Combine `experience` column with `exp` column into a new column `experience_` using `combine_first`.
# - Replace 'Unknown' values in `no_exp` column with `NaN`.
# - Combine `num_of_exp` column with `no_exp` column into a new column `num_of_exp_years` using `combine_first`.

# %%
df_egypt['exp'].replace('Unknown', np.nan, inplace=True)
df_egypt['experience_'] = df_egypt['experience'].combine_first(df_egypt['exp'])
df_egypt['no_exp'].replace('Unknown', np.nan, inplace=True)
df_egypt['num_of_exp_years'] = df_egypt['num_of_exp'].combine_first(df_egypt['no_exp'])
df_egypt.head(15)
# Out:
#     Unnamed: 0                                               link  \
# 0            0  https://www.bayt.com/ar/egypt/jobs/%D9%81%D9%8...
# 1            1  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%A...
# 2            2  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 3            3  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 4            4  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 5            5  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%A...
# 6            6  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 7            7  https://www.bayt.com/ar/egypt/jobs/%D8%A7%D9%8...
# 8            8  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%B...
# 9            9  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%A...
# 10          10  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 11          11  https://www.bayt.com/ar/egypt/jobs/%D8%B3%D9%8...
# 12          12  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%B...
# 13          13  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 14          14  https://www.bayt.com/ar/egypt/jobs/%D8%B9%D8%B...
#
#                            title        date           salary  \
# 0    فنى صيانة معدات (ميكانيكا )       اليوم  $1,500 - $2,000
# 1   متخصص فى مجال السوشيال ميديا    في الامس              NaN
# 2                    موظف مبيعات    في الامس              NaN
# 3                    موظف مبيعات    في الامس              NaN
# 4                   مندوب مبيعات    في الامس        $0 - $500
# 5     مدير انتاج للعمل بالسعودية   قبل يومين              NaN
# 6                   مندوب مبيعات   قبل يومين              NaN
# 7                     امين مخازن  قبل 3 أيام              NaN
# 8        مسئول التسويق والمبيعات  قبل 5 أيام              NaN
# 9                    مدير مبيعات  قبل 5 أيام              NaN
# 10                  مندوب مبيعات  قبل 6 أيام              NaN
# 11               سكرتيرة تنفيذية  قبل 6 أيام              NaN
# 12  مشرف انتاج من الاسكندرية فقط  قبل 6 أيام              NaN
# 13                مهندس مكتب فني  قبل 7 أيام              NaN
# 14                      عضو فريق  قبل 9 أيام              NaN
#
#                                       career_level  \
# 0                                        دوام كامل
# 1        دوام جزئي · الحد الأدنى 3 سنوات من الخبرة
# 2                  دوام كامل · 1-3 سنوات من الخبرة
# 3                  دوام كامل · 1-3 سنوات من الخبرة
# 4                                        دوام كامل
# 5                                        دوام كامل
# 6   دوام كامل · مبتدئ الخبرة · 0-1 سنوات من الخبرة
# 7   دوام كامل · متوسط الخبرة · 1-2 سنوات من الخبرة
# 8                                        دوام كامل
# 9                                        دوام كامل
# 10  دوام كامل · مبتدئ الخبرة · 0-5 سنوات من الخبرة
# 11                               دوام كامل · إدارة
# 12                                       دوام كامل
# 13                                       دوام كامل
# 14                                       دوام كامل
#
#                            location        num_of_vacancies  \
# 0       العامرية · الإسكندرية · مصر                     NaN
# 1                     القاهرة · مصر  الوظائف المتاحة عدد 10
# 2   القاهرة الجديدة · القاهرة · مصر                     NaN
# 3   القاهرة الجديدة · القاهرة · مصر                     NaN
# 4                  منية النصر · مصر  الوظائف المتاحة عدد 20
# 5         هليوبوليس · القاهرة · مصر                     NaN
# 6                   شرم الشيخ · مصر   الوظائف المتاحة عدد 3
# 7                   شرم الشيخ · مصر   الوظائف المتاحة عدد 2
# 8                     القاهرة · مصر                     NaN
# 9                               مصر                     NaN
# 10                      قليوب · مصر   الوظائف المتاحة عدد 6
# 11        مدينة نصر · القاهرة · مصر                     NaN
# 12      العامرية · الإسكندرية · مصر                     NaN
# 13         6 أكتوبر · القاهرة · مصر                     NaN
# 14                              مصر  الوظائف المتاحة عدد 39
#
#                                              industry  \
# 0               10-49 موظف · إنتاج الأغذية والمشروبات
# 1   10-49 موظف · الإنترنت والتجارة الإلكترونية - أ...
# 2                         10-49 موظف · وكلاء السيارات
# 3   10-49 موظف · صيانة السيارات وقطع الغيار وخدمات...
# 4                10-49 موظف · البيع بالتجزئة وبالجملة
# 5                         10-49 موظف · وكالات التوظيف
# 6                                50-99 موظف · التجارة
# 7                                50-99 موظف · التجارة
# 8                    1-9 موظف · التسويق - أبحاث السوق
# 9                                  1-9 موظف · التسويق
# 10                     50-99 موظف · المستشفيات الطبية
# 11                         1-9 موظف · البناء والتشييد
# 12              10-49 موظف · إنتاج الأغذية والمشروبات
# 13               10-49 موظف · توليد الطاقة الكهربائية
# 14           500 موظف أو أكثر · المطاعم وخدمات الطعام
#
#                                           description  ...  \
# 0   مطلوب فنى صيانة ميكانيكا معدات - لمصنع مخبوزات...  ...
# 1   متخصص فى مجال السوشيال ميديا ( الفيس بوك - الا...  ...
# 2   الحفاظ على سجلات المبيعات والتسليم ، وكذلك تحق...  ...
# 3   الحفاظ على سجلات المبيعات والتسليم ، وكذلك تحق...  ...
# 4   مندوب مبيعات سجائر الكتروني في محيط القاهرة وا...  ...
# 5   إدارة وتنظيم عمليات الإنتاج اليومية لضمان تحقي...  ...
# 6   المسمي الوظيفي : مندوب مبيعات المدير المباشر و...  ...
# 7   المسمي الوظيفي : امين مخازنالمدير المباشر : مد...  ...
# 8   إعلان وظيفي: مسئول التسويق والمبيعاتشركة أنظمة...  ...
# 9   فرصة عمل في Vixilia Agency – مدير مبيعات (Sale...  ...
# 10  المناديب المطلوبة مناطق ( القاهرة - الجيزة - ا...  ...
# 11  المهام والمسؤوليات:• تنظيم جدول المدير التنفيذ...  ...
# 12  إدارة الإنتاج: تنظيم وتخطيط عمليات الإنتاج لضم...  ...
# 13  مهندس مكتب فني تصميمات مصنع تشكيل معادن تصنيع ...  ...
# 14  شخص ودود، مرن، ومستعد للتعاون والعمل مع أعضاء ...  ...
#
#                                 age specialization    experience  \
# 0                               NaN            NaN           NaN
# 1   الحد الأدنى: 25 الحد الأقصى: 50           بدون           NaN
# 2   الحد الأدنى: 22 الحد الأقصى: 28            NaN           NaN
# 3   الحد الأدنى: 22 الحد الأقصى: 28            NaN           NaN
# 4                               NaN            NaN           NaN
# 5                               NaN            NaN           NaN
# 6   الحد الأدنى: 25 الحد الأقصى: 31       المبيعات  مبتدئ الخبرة
# 7   الحد الأدنى: 25 الحد الأقصى: 31          مخازن  متوسط الخبرة
# 8                               NaN            NaN           NaN
# 9                               NaN            NaN           NaN
# 10  الحد الأدنى: 22 الحد الأقصى: 40       المبيعات  مبتدئ الخبرة
# 11                              NaN            NaN         إدارة
# 12                              NaN            NaN           NaN
# 13                              NaN            NaN           NaN
# 14  الحد الأدنى: 18 الحد الأقصى: 35            NaN           NaN
#
#                                 company_name        city       type  \
# 0                      Alexandrina for trade  الإسكندرية  دوام كامل
# 1     المجموعة الدولية لحلول الملكية الفكرية     القاهرة  دوام جزئي
# 2                                 awija auto     القاهرة  دوام كامل
# 3                                 awija auto     القاهرة  دوام كامل
# 4                    Almanna Import & Export  منية النصر  دوام كامل
# 5   شركة البدوي للتوظيف/ Albadwy Recruitment     القاهرة  دوام كامل
# 6                            sittin egy food   شرم الشيخ  دوام كامل
# 7                            sittin egy food   شرم الشيخ  دوام كامل
# 8             الشربيني لأنظمة البناء الداخلي     القاهرة  دوام كامل
# 9                              وكالة فيكسليا     Unknown  دوام كامل
# 10                       Egyptian Italian co       قليوب  دوام كامل
# 11            الشربيني لأنظمة البناء الداخلي     القاهرة  دوام كامل
# 12                     Alexandrina for trade  الإسكندرية  دوام كامل
# 13                           Sun Energy Tech     القاهرة  دوام كامل
# 14                           مطاعم واحد مشوى     Unknown  دوام كامل
#
#              exp                         no_exp   experience_  \
# 0            NaN                            NaN           NaN
# 1            NaN  الحد الأدنى 3 سنوات من الخبرة           NaN
# 2            NaN            1-3 سنوات من الخبرة           NaN
# 3            NaN            1-3 سنوات من الخبرة           NaN
# 4            NaN                            NaN           NaN
# 5            NaN                            NaN           NaN
# 6   مبتدئ الخبرة            0-1 سنوات من الخبرة  مبتدئ الخبرة
# 7   متوسط الخبرة            1-2 سنوات من الخبرة  متوسط الخبرة
# 8            NaN                            NaN           NaN
# 9            NaN                            NaN           NaN
# 10  مبتدئ الخبرة            0-5 سنوات من الخبرة  مبتدئ الخبرة
# 11         إدارة                            NaN         إدارة
# 12           NaN                            NaN           NaN
# 13           NaN                            NaN           NaN
# 14           NaN                            NaN           NaN
#
#                  num_of_exp_years
# 0                             NaN
# 1                  الحد الأدنى: 3
# 2   الحد الأدنى: 1 الحد الأقصى: 3
# 3   الحد الأدنى: 1 الحد الأقصى: 3
# 4                             NaN
# 5                             NaN
# 6   الحد الأدنى: 0 الحد الأقصى: 1
# 7   الحد الأدنى: 1 الحد الأقصى: 2
# 8                             NaN
# 9                             NaN
# 10  الحد الأدنى: 0 الحد الأقصى: 5
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
#
# [15 rows x 27 columns]

# %% [markdown]
# ### Split and Clean Columns
# 1. **Split `industry` column** using the `split_industry` function.
# 2. **Split `location` column**:
#    - Extract the city from the `location` column by splitting at '·'.
#    - The resulting values are stored in the new `city` column, reversing the split.
# 3. **Split `num_of_vacancies` column**:
#    - Extract the number of vacancies by splitting at a space (' ').
#    - Fill missing values with `1` if no vacancies are specified.

# %%
split_industry(df_egypt)
split_column(df_egypt, 'location', index=[1], split_char='·', names=['city'], reverse=True)
split_column(df_egypt, 'num_of_vacancies', index=[3], split_char=' ', names=['num_of_vacancies'], fill_value=1)
df_egypt.head(15)
# Out:
#     Unnamed: 0                                               link  \
# 0            0  https://www.bayt.com/ar/egypt/jobs/%D9%81%D9%8...
# 1            1  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%A...
# 2            2  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 3            3  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 4            4  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 5            5  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%A...
# 6            6  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 7            7  https://www.bayt.com/ar/egypt/jobs/%D8%A7%D9%8...
# 8            8  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%B...
# 9            9  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%A...
# 10          10  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 11          11  https://www.bayt.com/ar/egypt/jobs/%D8%B3%D9%8...
# 12          12  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%B...
# 13          13  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 14          14  https://www.bayt.com/ar/egypt/jobs/%D8%B9%D8%B...
#
#                            title        date           salary  \
# 0    فنى صيانة معدات (ميكانيكا )       اليوم  $1,500 - $2,000
# 1   متخصص فى مجال السوشيال ميديا    في الامس              NaN
# 2                    موظف مبيعات    في الامس              NaN
# 3                    موظف مبيعات    في الامس              NaN
# 4                   مندوب مبيعات    في الامس        $0 - $500
# 5     مدير انتاج للعمل بالسعودية   قبل يومين              NaN
# 6                   مندوب مبيعات   قبل يومين              NaN
# 7                     امين مخازن  قبل 3 أيام              NaN
# 8        مسئول التسويق والمبيعات  قبل 5 أيام              NaN
# 9                    مدير مبيعات  قبل 5 أيام              NaN
# 10                  مندوب مبيعات  قبل 6 أيام              NaN
# 11               سكرتيرة تنفيذية  قبل 6 أيام              NaN
# 12  مشرف انتاج من الاسكندرية فقط  قبل 6 أيام              NaN
# 13                مهندس مكتب فني  قبل 7 أيام              NaN
# 14                      عضو فريق  قبل 9 أيام              NaN
#
#                                       career_level  \
# 0                                        دوام كامل
# 1        دوام جزئي · الحد الأدنى 3 سنوات من الخبرة
# 2                  دوام كامل · 1-3 سنوات من الخبرة
# 3                  دوام كامل · 1-3 سنوات من الخبرة
# 4                                        دوام كامل
# 5                                        دوام كامل
# 6   دوام كامل · مبتدئ الخبرة · 0-1 سنوات من الخبرة
# 7   دوام كامل · متوسط الخبرة · 1-2 سنوات من الخبرة
# 8                                        دوام كامل
# 9                                        دوام كامل
# 10  دوام كامل · مبتدئ الخبرة · 0-5 سنوات من الخبرة
# 11                               دوام كامل · إدارة
# 12                                       دوام كامل
# 13                                       دوام كامل
# 14                                       دوام كامل
#
#                            location num_of_vacancies  \
# 0       العامرية · الإسكندرية · مصر                1
# 1                     القاهرة · مصر               10
# 2   القاهرة الجديدة · القاهرة · مصر                1
# 3   القاهرة الجديدة · القاهرة · مصر                1
# 4                  منية النصر · مصر               20
# 5         هليوبوليس · القاهرة · مصر                1
# 6                   شرم الشيخ · مصر                3
# 7                   شرم الشيخ · مصر                2
# 8                     القاهرة · مصر                1
# 9                               مصر                1
# 10                      قليوب · مصر                6
# 11        مدينة نصر · القاهرة · مصر                1
# 12      العامرية · الإسكندرية · مصر                1
# 13         6 أكتوبر · القاهرة · مصر                1
# 14                              مصر               39
#
#                                              industry  \
# 0               10-49 موظف · إنتاج الأغذية والمشروبات
# 1   10-49 موظف · الإنترنت والتجارة الإلكترونية - أ...
# 2                         10-49 موظف · وكلاء السيارات
# 3   10-49 موظف · صيانة السيارات وقطع الغيار وخدمات...
# 4                10-49 موظف · البيع بالتجزئة وبالجملة
# 5                         10-49 موظف · وكالات التوظيف
# 6                                50-99 موظف · التجارة
# 7                                50-99 موظف · التجارة
# 8                    1-9 موظف · التسويق - أبحاث السوق
# 9                                  1-9 موظف · التسويق
# 10                     50-99 موظف · المستشفيات الطبية
# 11                         1-9 موظف · البناء والتشييد
# 12              10-49 موظف · إنتاج الأغذية والمشروبات
# 13               10-49 موظف · توليد الطاقة الكهربائية
# 14           500 موظف أو أكثر · المطاعم وخدمات الطعام
#
#                                           description  ...    experience  \
# 0   مطلوب فنى صيانة ميكانيكا معدات - لمصنع مخبوزات...  ...           NaN
# 1   متخصص فى مجال السوشيال ميديا ( الفيس بوك - الا...  ...           NaN
# 2   الحفاظ على سجلات المبيعات والتسليم ، وكذلك تحق...  ...           NaN
# 3   الحفاظ على سجلات المبيعات والتسليم ، وكذلك تحق...  ...           NaN
# 4   مندوب مبيعات سجائر الكتروني في محيط القاهرة وا...  ...           NaN
# 5   إدارة وتنظيم عمليات الإنتاج اليومية لضمان تحقي...  ...           NaN
# 6   المسمي الوظيفي : مندوب مبيعات المدير المباشر و...  ...  مبتدئ الخبرة
# 7   المسمي الوظيفي : امين مخازنالمدير المباشر : مد...  ...  متوسط الخبرة
# 8   إعلان وظيفي: مسئول التسويق والمبيعاتشركة أنظمة...  ...           NaN
# 9   فرصة عمل في Vixilia Agency – مدير مبيعات (Sale...  ...           NaN
# 10  المناديب المطلوبة مناطق ( القاهرة - الجيزة - ا...  ...  مبتدئ الخبرة
# 11  المهام والمسؤوليات:• تنظيم جدول المدير التنفيذ...  ...         إدارة
# 12  إدارة الإنتاج: تنظيم وتخطيط عمليات الإنتاج لضم...  ...           NaN
# 13  مهندس مكتب فني تصميمات مصنع تشكيل معادن تصنيع ...  ...           NaN
# 14  شخص ودود، مرن، ومستعد للتعاون والعمل مع أعضاء ...  ...           NaN
#
#                                 company_name        city       type  \
# 0                      Alexandrina for trade  الإسكندرية  دوام كامل
# 1     المجموعة الدولية لحلول الملكية الفكرية     القاهرة  دوام جزئي
# 2                                 awija auto     القاهرة  دوام كامل
# 3                                 awija auto     القاهرة  دوام كامل
# 4                    Almanna Import & Export  منية النصر  دوام كامل
# 5   شركة البدوي للتوظيف/ Albadwy Recruitment     القاهرة  دوام كامل
# 6                            sittin egy food   شرم الشيخ  دوام كامل
# 7                            sittin egy food   شرم الشيخ  دوام كامل
# 8             الشربيني لأنظمة البناء الداخلي     القاهرة  دوام كامل
# 9                              وكالة فيكسليا     Unknown  دوام كامل
# 10                       Egyptian Italian co       قليوب  دوام كامل
# 11            الشربيني لأنظمة البناء الداخلي     القاهرة  دوام كامل
# 12                     Alexandrina for trade  الإسكندرية  دوام كامل
# 13                           Sun Energy Tech     القاهرة  دوام كامل
# 14                           مطاعم واحد مشوى     Unknown  دوام كامل
#
#              exp                         no_exp   experience_  \
# 0            NaN                            NaN           NaN
# 1            NaN  الحد الأدنى 3 سنوات من الخبرة           NaN
# 2            NaN            1-3 سنوات من الخبرة           NaN
# 3            NaN            1-3 سنوات من الخبرة           NaN
# 4            NaN                            NaN           NaN
# 5            NaN                            NaN           NaN
# 6   مبتدئ الخبرة            0-1 سنوات من الخبرة  مبتدئ الخبرة
# 7   متوسط الخبرة            1-2 سنوات من الخبرة  متوسط الخبرة
# 8            NaN                            NaN           NaN
# 9            NaN                            NaN           NaN
# 10  مبتدئ الخبرة            0-5 سنوات من الخبرة  مبتدئ الخبرة
# 11         إدارة                            NaN         إدارة
# 12           NaN                            NaN           NaN
# 13           NaN                            NaN           NaN
# 14           NaN                            NaN           NaN
#
#                  num_of_exp_years  \
# 0                             NaN
# 1                  الحد الأدنى: 3
# 2   الحد الأدنى: 1 الحد الأقصى: 3
# 3   الحد الأدنى: 1 الحد الأقصى: 3
# 4                             NaN
# 5                             NaN
# 6   الحد الأدنى: 0 الحد الأقصى: 1
# 7   الحد الأدنى: 1 الحد الأقصى: 2
# 8                             NaN
# 9                             NaN
# 10  الحد الأدنى: 0 الحد الأقصى: 5
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
#
#                                       industry_      company_size
# 0                      إنتاج الأغذية والمشروبات        10-49 موظف
# 1   الإنترنت والتجارة الإلكترونية - أبحاث السوق        10-49 موظف
# 2                                وكلاء السيارات        10-49 موظف
# 3       صيانة السيارات وقطع الغيار وخدمات الدعم        10-49 موظف
# 4                       البيع بالتجزئة وبالجملة        10-49 موظف
# 5                                وكالات التوظيف        10-49 موظف
# 6                                       التجارة        50-99 موظف
# 7                                       التجارة        50-99 موظف
# 8                         التسويق - أبحاث السوق          1-9 موظف
# 9                                       التسويق          1-9 موظف
# 10                            المستشفيات الطبية        50-99 موظف
# 11                              البناء والتشييد          1-9 موظف
# 12                     إنتاج الأغذية والمشروبات        10-49 موظف
# 13                      توليد الطاقة الكهربائية        10-49 موظف
# 14                        المطاعم وخدمات الطعام  500 موظف أو أكثر
#
# [15 rows x 29 columns]

# %% [markdown]
# ### Fill Missing Values in Columns
# 1. **Fill missing values in the `remote` column** with `'من المقر'` to indicate office-based positions.
# 2. **Fill missing values in the `age` column** with `'لا تفضيل'` to represent no preference regarding age.
# 3. **Fill missing values in the `sex` column** with `'لا تفضيل'` to represent no preference regarding sex.
# 4. **Fill missing values in the `experience_` column** with `'لا تفضيل'` to represent no preference regarding experience.
# 5. **Fill missing values in the `num_of_exp_years` column** with `'لا تفضيل'` to represent no preference regarding years of experience.

# %%
df_egypt['remote'].fillna('من المقر', inplace=True)
df_egypt['age'].fillna('لا تفضيل', inplace=True)
df_egypt['sex'].fillna('لا تفضيل', inplace=True)
df_egypt['experience_'].fillna('لا تفضيل', inplace=True)
df_egypt['num_of_exp_years'].fillna('لا تفضيل', inplace=True)
df_egypt.head(15)
# Out:
#     Unnamed: 0                                               link  \
# 0            0  https://www.bayt.com/ar/egypt/jobs/%D9%81%D9%8...
# 1            1  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%A...
# 2            2  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 3            3  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 4            4  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 5            5  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%A...
# 6            6  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 7            7  https://www.bayt.com/ar/egypt/jobs/%D8%A7%D9%8...
# 8            8  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%B...
# 9            9  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%A...
# 10          10  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 11          11  https://www.bayt.com/ar/egypt/jobs/%D8%B3%D9%8...
# 12          12  https://www.bayt.com/ar/egypt/jobs/%D9%85%D8%B...
# 13          13  https://www.bayt.com/ar/egypt/jobs/%D9%85%D9%8...
# 14          14  https://www.bayt.com/ar/egypt/jobs/%D8%B9%D8%B...
#
#                            title        date           salary  \
# 0    فنى صيانة معدات (ميكانيكا )       اليوم  $1,500 - $2,000
# 1   متخصص فى مجال السوشيال ميديا    في الامس              NaN
# 2                    موظف مبيعات    في الامس              NaN
# 3                    موظف مبيعات    في الامس              NaN
# 4                   مندوب مبيعات    في الامس        $0 - $500
# 5     مدير انتاج للعمل بالسعودية   قبل يومين              NaN
# 6                   مندوب مبيعات   قبل يومين              NaN
# 7                     امين مخازن  قبل 3 أيام              NaN
# 8        مسئول التسويق والمبيعات  قبل 5 أيام              NaN
# 9                    مدير مبيعات  قبل 5 أيام              NaN
# 10                  مندوب مبيعات  قبل 6 أيام              NaN
# 11               سكرتيرة تنفيذية  قبل 6 أيام              NaN
# 12  مشرف انتاج من الاسكندرية فقط  قبل 6 أيام              NaN
# 13                مهندس مكتب فني  قبل 7 أيام              NaN
# 14                      عضو فريق  قبل 9 أيام              NaN
#
#                                       career_level  \
# 0                                        دوام كامل
# 1        دوام جزئي · الحد الأدنى 3 سنوات من الخبرة
# 2                  دوام كامل · 1-3 سنوات من الخبرة
# 3                  دوام كامل · 1-3 سنوات من الخبرة
# 4                                        دوام كامل
# 5                                        دوام كامل
# 6   دوام كامل · مبتدئ الخبرة · 0-1 سنوات من الخبرة
# 7   دوام كامل · متوسط الخبرة · 1-2 سنوات من الخبرة
# 8                                        دوام كامل
# 9                                        دوام كامل
# 10  دوام كامل · مبتدئ الخبرة · 0-5 سنوات من الخبرة
# 11                               دوام كامل · إدارة
# 12                                       دوام كامل
# 13                                       دوام كامل
# 14                                       دوام كامل
#
#                            location num_of_vacancies  \
# 0       العامرية · الإسكندرية · مصر                1
# 1                     القاهرة · مصر               10
# 2   القاهرة الجديدة · القاهرة · مصر                1
# 3   القاهرة الجديدة · القاهرة · مصر                1
# 4                  منية النصر · مصر               20
# 5         هليوبوليس · القاهرة · مصر                1
# 6                   شرم الشيخ · مصر                3
# 7                   شرم الشيخ · مصر                2
# 8                     القاهرة · مصر                1
# 9                               مصر                1
# 10                      قليوب · مصر                6
# 11        مدينة نصر · القاهرة · مصر                1
# 12      العامرية · الإسكندرية · مصر                1
# 13         6 أكتوبر · القاهرة · مصر                1
# 14                              مصر               39
#
#                                              industry  \
# 0               10-49 موظف · إنتاج الأغذية والمشروبات
# 1   10-49 موظف · الإنترنت والتجارة الإلكترونية - أ...
# 2                         10-49 موظف · وكلاء السيارات
# 3   10-49 موظف · صيانة السيارات وقطع الغيار وخدمات...
# 4                10-49 موظف · البيع بالتجزئة وبالجملة
# 5                         10-49 موظف · وكالات التوظيف
# 6                                50-99 موظف · التجارة
# 7                                50-99 موظف · التجارة
# 8                    1-9 موظف · التسويق - أبحاث السوق
# 9                                  1-9 موظف · التسويق
# 10                     50-99 موظف · المستشفيات الطبية
# 11                         1-9 موظف · البناء والتشييد
# 12              10-49 موظف · إنتاج الأغذية والمشروبات
# 13               10-49 موظف · توليد الطاقة الكهربائية
# 14           500 موظف أو أكثر · المطاعم وخدمات الطعام
#
#                                           description  ...    experience  \
# 0   مطلوب فنى صيانة ميكانيكا معدات - لمصنع مخبوزات...  ...           NaN
# 1   متخصص فى مجال السوشيال ميديا ( الفيس بوك - الا...  ...           NaN
# 2   الحفاظ على سجلات المبيعات والتسليم ، وكذلك تحق...  ...           NaN
# 3   الحفاظ على سجلات المبيعات والتسليم ، وكذلك تحق...  ...           NaN
# 4   مندوب مبيعات سجائر الكتروني في محيط القاهرة وا...  ...           NaN
# 5   إدارة وتنظيم عمليات الإنتاج اليومية لضمان تحقي...  ...           NaN
# 6   المسمي الوظيفي : مندوب مبيعات المدير المباشر و...  ...  مبتدئ الخبرة
# 7   المسمي الوظيفي : امين مخازنالمدير المباشر : مد...  ...  متوسط الخبرة
# 8   إعلان وظيفي: مسئول التسويق والمبيعاتشركة أنظمة...  ...           NaN
# 9   فرصة عمل في Vixilia Agency – مدير مبيعات (Sale...  ...           NaN
# 10  المناديب المطلوبة مناطق ( القاهرة - الجيزة - ا...  ...  مبتدئ الخبرة
# 11  المهام والمسؤوليات:• تنظيم جدول المدير التنفيذ...  ...         إدارة
# 12  إدارة الإنتاج: تنظيم وتخطيط عمليات الإنتاج لضم...  ...           NaN
# 13  مهندس مكتب فني تصميمات مصنع تشكيل معادن تصنيع ...  ...           NaN
# 14  شخص ودود، مرن، ومستعد للتعاون والعمل مع أعضاء ...  ...           NaN
#
#                                 company_name        city       type  \
# 0                      Alexandrina for trade  الإسكندرية  دوام كامل
# 1     المجموعة الدولية لحلول الملكية الفكرية     القاهرة  دوام جزئي
# 2                                 awija auto     القاهرة  دوام كامل
# 3                                 awija auto     القاهرة  دوام كامل
# 4                    Almanna Import & Export  منية النصر  دوام كامل
# 5   شركة البدوي للتوظيف/ Albadwy Recruitment     القاهرة  دوام كامل
# 6                            sittin egy food   شرم الشيخ  دوام كامل
# 7                            sittin egy food   شرم الشيخ  دوام كامل
# 8             الشربيني لأنظمة البناء الداخلي     القاهرة  دوام كامل
# 9                              وكالة فيكسليا     Unknown  دوام كامل
# 10                       Egyptian Italian co       قليوب  دوام كامل
# 11            الشربيني لأنظمة البناء الداخلي     القاهرة  دوام كامل
# 12                     Alexandrina for trade  الإسكندرية  دوام كامل
# 13                           Sun Energy Tech     القاهرة  دوام كامل
# 14                           مطاعم واحد مشوى     Unknown  دوام كامل
#
#              exp                         no_exp   experience_  \
# 0            NaN                            NaN      لا تفضيل
# 1            NaN  الحد الأدنى 3 سنوات من الخبرة      لا تفضيل
# 2            NaN            1-3 سنوات من الخبرة      لا تفضيل
# 3            NaN            1-3 سنوات من الخبرة      لا تفضيل
# 4            NaN                            NaN      لا تفضيل
# 5            NaN                            NaN      لا تفضيل
# 6   مبتدئ الخبرة            0-1 سنوات من الخبرة  مبتدئ الخبرة
# 7   متوسط الخبرة            1-2 سنوات من الخبرة  متوسط الخبرة
# 8            NaN                            NaN      لا تفضيل
# 9            NaN                            NaN      لا تفضيل
# 10  مبتدئ الخبرة            0-5 سنوات من الخبرة  مبتدئ الخبرة
# 11         إدارة                            NaN         إدارة
# 12           NaN                            NaN      لا تفضيل
# 13           NaN                            NaN      لا تفضيل
# 14           NaN                            NaN      لا تفضيل
#
#                  num_of_exp_years  \
# 0                        لا تفضيل
# 1                  الحد الأدنى: 3
# 2   الحد الأدنى: 1 الحد الأقصى: 3
# 3   الحد الأدنى: 1 الحد الأقصى: 3
# 4                        لا تفضيل
# 5                        لا تفضيل
# 6   الحد الأدنى: 0 الحد الأقصى: 1
# 7   الحد الأدنى: 1 الحد الأقصى: 2
# 8                        لا تفضيل
# 9                        لا تفضيل
# 10  الحد الأدنى: 0 الحد الأقصى: 5
# 11                       لا تفضيل
# 12                       لا تفضيل
# 13                       لا تفضيل
# 14                       لا تفضيل
#
#                                       industry_      company_size
# 0                      إنتاج الأغذية والمشروبات        10-49 موظف
# 1   الإنترنت والتجارة الإلكترونية - أبحاث السوق        10-49 موظف
# 2                                وكلاء السيارات        10-49 موظف
# 3       صيانة السيارات وقطع الغيار وخدمات الدعم        10-49 موظف
# 4                       البيع بالتجزئة وبالجملة        10-49 موظف
# 5                                وكالات التوظيف        10-49 موظف
# 6                                       التجارة        50-99 موظف
# 7                                       التجارة        50-99 موظف
# 8                         التسويق - أبحاث السوق          1-9 موظف
# 9                                       التسويق          1-9 موظف
# 10                            المستشفيات الطبية        50-99 موظف
# 11                              البناء والتشييد          1-9 موظف
# 12                     إنتاج الأغذية والمشروبات        10-49 موظف
# 13                      توليد الطاقة الكهربائية        10-49 موظف
# 14                        المطاعم وخدمات الطعام  500 موظف أو أكثر
#
# [15 rows x 29 columns]

# %% [markdown]
# ### Drop Unnecessary Columns
#  * **Remove columns** from the DataFrame that are not needed for further analysis:
#    - `age`, `exp`, `no_exp`, `num_of_exp`, `experience`, `career_level`, `industry`, `location`, `link`, `Unnamed: 0`, `salary`, `nationality`, `residence_area`, `qualification`, `specialization`.

# %%
df_egypt.drop(
    columns=['age', 'exp', 'no_exp', 'num_of_exp', 'exp', 'experience', 'career_level', 'industry', 'location', 'link',
             'Unnamed: 0', 'salary', 'nationality', 'residence_area', 'qualification', 'specialization'],
    inplace=True)
df_egypt.head(15)
# Out:
#                            title        date num_of_vacancies  \
# 0    فنى صيانة معدات (ميكانيكا )       اليوم                1
# 1   متخصص فى مجال السوشيال ميديا    في الامس               10
# 2                    موظف مبيعات    في الامس                1
# 3                    موظف مبيعات    في الامس                1
# 4                   مندوب مبيعات    في الامس               20
# 5     مدير انتاج للعمل بالسعودية   قبل يومين                1
# 6                   مندوب مبيعات   قبل يومين                3
# 7                     امين مخازن  قبل 3 أيام                2
# 8        مسئول التسويق والمبيعات  قبل 5 أيام                1
# 9                    مدير مبيعات  قبل 5 أيام                1
# 10                  مندوب مبيعات  قبل 6 أيام                6
# 11               سكرتيرة تنفيذية  قبل 6 أيام                1
# 12  مشرف انتاج من الاسكندرية فقط  قبل 6 أيام                1
# 13                مهندس مكتب فني  قبل 7 أيام                1
# 14                      عضو فريق  قبل 9 أيام               39
#
#                                           description  \
# 0   مطلوب فنى صيانة ميكانيكا معدات - لمصنع مخبوزات...
# 1   متخصص فى مجال السوشيال ميديا ( الفيس بوك - الا...
# 2   الحفاظ على سجلات المبيعات والتسليم ، وكذلك تحق...
# 3   الحفاظ على سجلات المبيعات والتسليم ، وكذلك تحق...
# 4   مندوب مبيعات سجائر الكتروني في محيط القاهرة وا...
# 5   إدارة وتنظيم عمليات الإنتاج اليومية لضمان تحقي...
# 6   المسمي الوظيفي : مندوب مبيعات المدير المباشر و...
# 7   المسمي الوظيفي : امين مخازنالمدير المباشر : مد...
# 8   إعلان وظيفي: مسئول التسويق والمبيعاتشركة أنظمة...
# 9   فرصة عمل في Vixilia Agency – مدير مبيعات (Sale...
# 10  المناديب المطلوبة مناطق ( القاهرة - الجيزة - ا...
# 11  المهام والمسؤوليات:• تنظيم جدول المدير التنفيذ...
# 12  إدارة الإنتاج: تنظيم وتخطيط عمليات الإنتاج لضم...
# 13  مهندس مكتب فني تصميمات مصنع تشكيل معادن تصنيع ...
# 14  شخص ودود، مرن، ومستعد للتعاون والعمل مع أعضاء ...
#
#                                                skills    remote       sex  \
# 0   المهارات\nفهم تقني للمعدات: معرفة عميقة بأنواع...  من المقر  لا تفضيل
# 1   المهارات\nالعمل فى مجال السويال ميديا لعمل الا...      هجين       ذكر
# 2   المهارات\nالقدرة على تحفيز وتشجيع فريق العمل.إ...  من المقر      أنثى
# 3   المهارات\nامتلاك مهارات البيع المختلفة وإعداد ...  من المقر      أنثى
# 4   المهارات\nفهم وتحليل احتياجات العملاء والقدرة ...  من المقر  لا تفضيل
# 5   المهارات\nبكالوريوس في الهندسة زراعية أو علوم ...  من المقر  لا تفضيل
# 6   المهارات\nالشروط المطلوب توافرها :1- مؤهل عالي...  من المقر       ذكر
# 7   المهارات\n1- مؤهل عالي (يفضل بكالوريوس تجارة) ...  من المقر       ذكر
# 8   المهارات\nالمؤهلات والمهارات المطلوبةدرجة جامع...  من المقر  لا تفضيل
# 9   المهارات\nالمؤهلات والخبرات المطلوبة:🔸 خبرة لا...   عن بُعد  لا تفضيل
# 10  المهارات\nالتواصل الجيد مع الجهات لذيادة البيع...  من المقر  لا تفضيل
# 11  المهارات\nالمؤهلات والمهارات المطلوبة:• درجة ج...  من المقر  لا تفضيل
# 12  المهارات\nالحد الادنى للمؤهلات واشتراطات التعي...  من المقر  لا تفضيل
# 13  المهارات\nخبرة سنتين ع الـأقل فى التصميم يجيد ...  من المقر  لا تفضيل
# 14  المهارات\nخدمة العملاء والمبادرة بحسن السلوك. ...  من المقر  لا تفضيل
#
#                                 company_name        city       type  \
# 0                      Alexandrina for trade  الإسكندرية  دوام كامل
# 1     المجموعة الدولية لحلول الملكية الفكرية     القاهرة  دوام جزئي
# 2                                 awija auto     القاهرة  دوام كامل
# 3                                 awija auto     القاهرة  دوام كامل
# 4                    Almanna Import & Export  منية النصر  دوام كامل
# 5   شركة البدوي للتوظيف/ Albadwy Recruitment     القاهرة  دوام كامل
# 6                            sittin egy food   شرم الشيخ  دوام كامل
# 7                            sittin egy food   شرم الشيخ  دوام كامل
# 8             الشربيني لأنظمة البناء الداخلي     القاهرة  دوام كامل
# 9                              وكالة فيكسليا     Unknown  دوام كامل
# 10                       Egyptian Italian co       قليوب  دوام كامل
# 11            الشربيني لأنظمة البناء الداخلي     القاهرة  دوام كامل
# 12                     Alexandrina for trade  الإسكندرية  دوام كامل
# 13                           Sun Energy Tech     القاهرة  دوام كامل
# 14                           مطاعم واحد مشوى     Unknown  دوام كامل
#
#      experience_               num_of_exp_years  \
# 0       لا تفضيل                       لا تفضيل
# 1       لا تفضيل                 الحد الأدنى: 3
# 2       لا تفضيل  الحد الأدنى: 1 الحد الأقصى: 3
# 3       لا تفضيل  الحد الأدنى: 1 الحد الأقصى: 3
# 4       لا تفضيل                       لا تفضيل
# 5       لا تفضيل                       لا تفضيل
# 6   مبتدئ الخبرة  الحد الأدنى: 0 الحد الأقصى: 1
# 7   متوسط الخبرة  الحد الأدنى: 1 الحد الأقصى: 2
# 8       لا تفضيل                       لا تفضيل
# 9       لا تفضيل                       لا تفضيل
# 10  مبتدئ الخبرة  الحد الأدنى: 0 الحد الأقصى: 5
# 11         إدارة                       لا تفضيل
# 12      لا تفضيل                       لا تفضيل
# 13      لا تفضيل                       لا تفضيل
# 14      لا تفضيل                       لا تفضيل
#
#                                       industry_      company_size
# 0                      إنتاج الأغذية والمشروبات        10-49 موظف
# 1   الإنترنت والتجارة الإلكترونية - أبحاث السوق        10-49 موظف
# 2                                وكلاء السيارات        10-49 موظف
# 3       صيانة السيارات وقطع الغيار وخدمات الدعم        10-49 موظف
# 4                       البيع بالتجزئة وبالجملة        10-49 موظف
# 5                                وكالات التوظيف        10-49 موظف
# 6                                       التجارة        50-99 موظف
# 7                                       التجارة        50-99 موظف
# 8                         التسويق - أبحاث السوق          1-9 موظف
# 9                                       التسويق          1-9 موظف
# 10                            المستشفيات الطبية        50-99 موظف
# 11                              البناء والتشييد          1-9 موظف
# 12                     إنتاج الأغذية والمشروبات        10-49 موظف
# 13                      توليد الطاقة الكهربائية        10-49 موظف
# 14                        المطاعم وخدمات الطعام  500 موظف أو أكثر

# %% [markdown]
# ### Analyze Date Data
# * **Call `analyses_date()` function** to analyze the date data in the DataFrame (`df`):
#    - Parameter `num_days=120` specifies the number of days to consider for analysis.

# %%
analyses_date(df_egypt, num_days=120)
df_egypt.head(15)
# Out:
#                                                   title       date  \
# 0                           فنى صيانة معدات (ميكانيكا ) 2025-04-15
# 3847                               Senior AP Accountant 2025-04-15
# 70                                 Sales Representative 2025-04-15
# 69    Customer Care Representative (Location:Zahraa ... 2025-04-15
# 494                                 Treasury Accountant 2025-04-15
# 350                                  Oracle HCM Analyst 2025-04-15
# 396                            Design Manager - Primary 2025-04-15
# 398                                 Operations Engineer 2025-04-15
# 351                          SAP Finance Senior Analyst 2025-04-15
# 279          People Technology Senior Specialist (HRIS) 2025-04-15
# 274                            IT Network Administrator 2025-04-15
# 272                              iSchool English Mentor 2025-04-15
# 251   Senior Analyst Wholesale Servicing Operations ... 2025-04-15
# 252                                       Sales Analyst 2025-04-15
# 253                    Human Resources Business Partner 2025-04-15
#
#      num_of_vacancies                                        description  \
# 0                   1  مطلوب فنى صيانة ميكانيكا معدات - لمصنع مخبوزات...
# 3847                1  Senior AP Accountant page is loaded Senior AP ...
# 70                  1  1.Responsible for the company's injection mold...
# 69                  1  Manage large amounts of inbound and outbound c...
# 494                 1  About Bosta: Launched in 2017, Bosta is an ove...
# 350                 1  Join our dynamic team and embark on a journey ...
# 396                 1  Job Description - Design Manager - Primary (25...
# 398                 1  Tagaddod is pioneering in the field of waste c...
# 351                 1  Join our dynamic team and embark on a journey ...
# 279                 1  Support and enhance the organization's People ...
# 274                 1  Install, configure, and troubleshoot network d...
# 272                 1  The iSchool Mentor plays a key role in support...
# 251                 1  Why join us? HSBC Commercial Banking operates ...
# 252                 1  About ILLA Distribution:At ILLA Distribution, ...
# 253                 1  Job DescriptionWork Arrangement: This role is ...
#
#                                                  skills    remote       sex  \
# 0     المهارات\nفهم تقني للمعدات: معرفة عميقة بأنواع...  من المقر  لا تفضيل
# 3847                                                NaN  من المقر  لا تفضيل
# 70    المهارات\n1.a mechanical professional backgrou...  من المقر  لا تفضيل
# 69    المهارات\nIt is also a Plus if they have:-Prev...  من المقر  لا تفضيل
# 494                                                 NaN  من المقر  لا تفضيل
# 350                                                 NaN  من المقر  لا تفضيل
# 396                                                 NaN  من المقر  لا تفضيل
# 398                                                 NaN  من المقر  لا تفضيل
# 351                                                 NaN  من المقر  لا تفضيل
# 279                                                 NaN  من المقر  لا تفضيل
# 274                                                 NaN  من المقر  لا تفضيل
# 272                                                 NaN   عن بُعد  لا تفضيل
# 251                                                 NaN  من المقر  لا تفضيل
# 252                                                 NaN  من المقر  لا تفضيل
# 253                                                 NaN  من المقر  لا تفضيل
#
#                          company_name        city       type experience_  \
# 0               Alexandrina for trade  الإسكندرية  دوام كامل    لا تفضيل
# 3847                      Technikland     القاهرة    Unknown    لا تفضيل
# 70    TOPSTAR WORLDWIDE GROUP LIMITED     القاهرة  دوام كامل    لا تفضيل
# 69                   Vodafone - Egypt     القاهرة  دوام كامل    لا تفضيل
# 494         Albostany for real estate     القاهرة    Unknown    لا تفضيل
# 350                         Accenture     القاهرة    Unknown    لا تفضيل
# 396        El Sewedy Electric Company     القاهرة    Unknown    لا تفضيل
# 398                          Tagaddod     Unknown    Unknown    لا تفضيل
# 351                         Accenture     القاهرة    Unknown    لا تفضيل
# 279                      Giza Systems     القاهرة    Unknown    لا تفضيل
# 274                      Giza Systems     القاهرة    Unknown    لا تفضيل
# 272                   iSchool Limited     Unknown    Unknown    لا تفضيل
# 251                              HSBC     القاهرة    Unknown    لا تفضيل
# 252                              illa     القاهرة    Unknown    لا تفضيل
# 253                    General Motors     Unknown    Unknown    لا تفضيل
#
#                    num_of_exp_years                   industry_  \
# 0                          لا تفضيل    إنتاج الأغذية والمشروبات
# 3847                       لا تفضيل  خدمات الدعم التجاري الأخرى
# 70    الحد الأدنى: 1 الحد الأقصى: 3         الهندسة الميكانيكية
# 69                         لا تفضيل          الاتصالات والشبكات
# 494                        لا تفضيل  خدمات الدعم التجاري الأخرى
# 350                        لا تفضيل  خدمات الدعم التجاري الأخرى
# 396                        لا تفضيل  خدمات الدعم التجاري الأخرى
# 398                        لا تفضيل  خدمات الدعم التجاري الأخرى
# 351                        لا تفضيل  خدمات الدعم التجاري الأخرى
# 279                        لا تفضيل              التعليم العالي
# 274                        لا تفضيل              التعليم العالي
# 272                        لا تفضيل  خدمات الدعم التجاري الأخرى
# 251                        لا تفضيل  خدمات الدعم التجاري الأخرى
# 252                        لا تفضيل  خدمات الدعم التجاري الأخرى
# 253                        لا تفضيل  خدمات الدعم التجاري الأخرى
#
#           company_size
# 0           10-49 موظف
# 3847           Unknown
# 70    500 موظف أو أكثر
# 69          50-99 موظف
# 494         10-49 موظف
# 350            Unknown
# 396            Unknown
# 398            Unknown
# 351            Unknown
# 279   500 موظف أو أكثر
# 274   500 موظف أو أكثر
# 272            Unknown
# 251            Unknown
# 252            Unknown
# 253            Unknown

# %% [markdown]
# ### Sort and Save Data
# 1. **Sort the DataFrame** by the 'title' column in descending order:
#    - The `ascending=False` argument sorts the data in descending order.
# 2. **Save the DataFrame to an SQLite database** (commented-out code)

# %%
df_egypt.sort_values(by=['title'], ascending=False, inplace=True)
# conn = sqlite3.connect('../database.db')
# df.to_sql('EGYPT', con=conn, if_exists='replace', index=False)

# %% [markdown]
# ### Manual Data Cleaning and Translation
# 1. **Manual Cleaning of 'title' Column**:
#    - Some manual adjustments were made to the 'title' column before starting the translation.
# 2. **Translate the 'title' Column**:
#    - After the manual cleaning, the translation was applied to the 'title' column for the first 400 rows using the `apply_translation` function.
# 3. **Save the Data**

# %%
df_egypt = pd.read_csv('../data/processed/egypt_clean.csv')
df_egypt.sort_values(by=['title'], ascending=False, inplace=True)
apply_translation(df_egypt, 'title', rows=df_egypt.iloc[:40, :].index.tolist())

# %%
df_egypt = df_egypt[~df_egypt['title'].str.contains('سعودية', na=False)]
df_egypt = df_egypt[~df_egypt['title'].str.contains('سعوديه', na=False)]
df_egypt = df_egypt[~df_egypt['title'].str.contains('سعوية', na=False)]
df_egypt = df_egypt[~df_egypt['title'].str.contains('saudi arabia', na=False)]
df_egypt = df_egypt[~df_egypt['title'].str.contains('saudi', na=False)]

# %% [markdown]
# ### Data Transformation Process
# 1. **Translation**:
#    - Translated 'experience_', 'type', 'sex', and 'remote' using respective translation functions.
# 2. **Gender Extraction**:
#    - Extracted gender information from 'title', 'description', and 'skills'.
# 3. **Remote Work Extraction**:
#    - Extracted remote work information from 'title', 'description', and 'skills'.
# 4. **Drop Irrelevant Columns**:
#    - Dropped 'description' and 'skills' columns.
# 5. **Split 'num_of_exp_years' Column**:
#    - Split and processed the 'num_of_exp_years' column.
# 6. **Save the Data**

# %%
df_egypt = pd.read_csv('../data/processed/egypt_clean.csv')

# %%
translate_experience(df_egypt)
translate_type(df_egypt)
translate_sex(df_egypt)
translate_remote(df_egypt)

# %%
extract_job_grade(df_egypt)
extract_gender(df_egypt, 'title')
extract_gender(df_egypt, 'description')
extract_gender(df_egypt, 'skills')
extract_remotely(df_egypt, 'title')
extract_remotely(df_egypt, 'description')
extract_remotely(df_egypt, 'skills')

# %%
df_egypt.drop(columns=['description', 'skills'], inplace=True)
split_num_of_exp_years(df_egypt)
conn = sqlite3.connect('../data/database.db')
# df.to_sql('EGYPT', con=conn, if_exists='replace', index=False)
conn.close()
df_egypt.head(15)
# Out:
#     Unnamed: 0                            title        date  num_of_vacancies  \
# 0           16                           waiter  2025-04-03                 1
# 1            2                   Sales employee  2025-04-14                 1
# 2            3                   Sales employee  2025-04-14                 1
# 3           25                   Sales employee  2025-03-22                 1
# 4           31              Mechanical engineer  2025-03-20                 1
# 5           13        Technical office engineer  2025-04-08                 1
# 6           19        Technical office engineer  2025-03-26                 1
# 7           30              Electrical engineer  2025-03-21                 1
# 8           67             Training coordinator  2025-03-15                 1
# 9           27             sales representative  2025-03-20                 4
# 10           4             sales representative  2025-04-14                20
# 11           6             sales representative  2025-04-13                 3
# 12          10             sales representative  2025-04-09                 6
# 13          66  Teacher of philosophy and logic  2025-03-15                 1
# 14          65                  History teacher  2025-03-15                 1
#
#      remote          qualification                              age  \
# 0   On-site                  دبلوم                         لا تفضيل
# 1   On-site                    NaN  الحد الأدنى: 22 الحد الأقصى: 28
# 2   On-site                    NaN  الحد الأدنى: 22 الحد الأقصى: 28
# 3   On-site                    NaN                  الحد الأقصى: 30
# 4   On-site                    NaN                         لا تفضيل
# 5   On-site                    NaN                         لا تفضيل
# 6   On-site                    NaN                         لا تفضيل
# 7   On-site                    NaN                         لا تفضيل
# 8   On-site                    NaN                         لا تفضيل
# 9   On-site                  دبلوم  الحد الأدنى: 21 الحد الأقصى: 30
# 10  On-site                    NaN                         لا تفضيل
# 11  On-site  بكالوريوس/ دبلوم عالي  الحد الأدنى: 25 الحد الأقصى: 31
# 12  On-site  بكالوريوس/ دبلوم عالي  الحد الأدنى: 22 الحد الأقصى: 40
# 13   Remote                    NaN                         لا تفضيل
# 14   Remote                    NaN                         لا تفضيل
#
#    specialization                            company_name        city  \
# 0             NaN                             كانتري هيلز     Unknown
# 1             NaN                              awija auto     القاهرة
# 2             NaN                              awija auto     القاهرة
# 3             NaN                              uptimecode     القاهرة
# 4             NaN                          United Coating  الإسكندرية
# 5             NaN                         Sun Energy Tech     القاهرة
# 6             NaN                                 Osirion     القاهرة
# 7             NaN                          United Coating  الإسكندرية
# 8             NaN  Raya Holding for Financial Investments       دمياط
# 9        المبيعات                           qenawy server     القاهرة
# 10            NaN                 Almanna Import & Export  منية النصر
# 11       المبيعات                         sittin egy food   شرم الشيخ
# 12       المبيعات                     Egyptian Italian co       قليوب
# 13            NaN                                   Nagwa     Unknown
# 14            NaN                                   Nagwa     Unknown
#
#          type                                          industry_  \
# 0   Full-Time                              المطاعم وخدمات الطعام
# 1   Full-Time                                     وكلاء السيارات
# 2   Full-Time            صيانة السيارات وقطع الغيار وخدمات الدعم
# 3   Part-Time                                    تطوير البرمجيات
# 4   Full-Time                            تصنيع المواد الكيميائية
# 5   Full-Time                            توليد الطاقة الكهربائية
# 6   Full-Time                                  الهندسة المعمارية
# 7   Full-Time                            تصنيع المواد الكيميائية
# 8     Unknown                                            Unknown
# 9   Part-Time  أمن المعلومات و الشبكات - صناعة أجهزة الكمبيوت...
# 10  Full-Time                            البيع بالتجزئة وبالجملة
# 11  Full-Time                                            التجارة
# 12  Full-Time                                  المستشفيات الطبية
# 13    Unknown                                    التعليم الثانوي
# 14    Unknown                                    التعليم الثانوي
#
#     company_size      job_level         gender min_num_of_years  \
# 0   100-499 موظف      Mid Level  No Preference                1
# 1     10-49 موظف  No Preference         Female                1
# 2     10-49 موظف  No Preference         Female                1
# 3       1-9 موظف  No Preference  No Preference          Unknown
# 4     50-99 موظف  No Preference  No Preference          Unknown
# 5     10-49 موظف  No Preference  No Preference          Unknown
# 6     10-49 موظف  No Preference  No Preference          Unknown
# 7     50-99 موظف  No Preference  No Preference          Unknown
# 8        Unknown  No Preference           Male          Unknown
# 9       1-9 موظف         Junior         Female                0
# 10    10-49 موظف  No Preference  No Preference          Unknown
# 11    50-99 موظف         Junior           Male                0
# 12    50-99 موظف         Junior  No Preference                0
# 13       Unknown  No Preference  No Preference          Unknown
# 14       Unknown  No Preference  No Preference          Unknown
#
#    max_num_of_years
# 0                 3
# 1                 3
# 2                 3
# 3           Unknown
# 4           Unknown
# 5           Unknown
# 6           Unknown
# 7           Unknown
# 8           Unknown
# 9                 3
# 10          Unknown
# 11                1
# 12                5
# 13          Unknown
# 14          Unknown

# %% [markdown]
# ### Data Transformation Steps for 'title' Column
# 1. **Remove Leading Numbers**:
#    - Removed leading numbers and periods (e.g., "1.", "2."), and stripped any leading or trailing spaces.
# 2. **Remove Leading "a"**:
#    - Removed any instance of the letter "a" at the beginning of the title followed by a space.
# 3. **Convert to Lowercase**:
#    - Converted all titles to lowercase for consistency.
# 4. **Sort Titles**:
#    - Sorted the titles alphabetically in ascending order.

# %%
conn = sqlite3.connect('../data/database.db')
df_egypt = pd.read_sql('SELECT * FROM EGYPT', conn)

# %%
df_egypt['title'] = df_egypt['title'].str.replace(r'^\d+\.', '', regex=True).str.strip()
df_egypt['title'] = df_egypt['title'].str.replace(r'^a\s\b', '', regex=True).str.strip()
df_egypt.title = df_egypt.title.str.lower()
df_egypt.sort_values(by=['title'], inplace=True)
df_egypt.head(15)
# Out:
#       index                                   title        date  \
# 4007   4007                             3d designer  2025-04-07
# 2675   2675                             3d designer  2025-03-26
# 4005   4005  3d visualizer ( interior & architect )  2025-02-25
# 4004   4004             a&r project manager (m/w/d)  2025-04-01
# 4003   4003                          a/c technician  2025-01-30
# 4002   4002                          a/c technician  2025-04-12
# 4001   4001                          a/r accountant  2025-04-09
# 4000   4000                          a/r accountant  2025-04-14
# 3822   3822                       account assistant  2025-03-05
# 3836   3836                       account assistant  2025-02-24
# 3835   3835                       account assistant  2025-04-12
# 3829   3829                       account assistant  2025-03-07
# 3828   3828                       account assistant  2025-02-21
# 3821   3821                       account assistant  2025-02-23
# 3820   3820                       account assistant  2025-04-04
#
#       num_of_vacancies   remote                         company_name  \
# 4007                 1  On-site                                  SSC
# 2675                 1  On-site                           Talent 360
# 4005                 1  On-site                           Talent 360
# 4004                 1  On-site                              Believe
# 4003                 1  On-site                     Palma Bay Rotana
# 4002                 1  On-site  Rotana Hotel Management Corporation
# 4001                 1  On-site    Rashideen Egypt for Trade Company
# 4000                 1  On-site                       KEY RECRUITERS
# 3822                 1   Remote                        ProjectGrowth
# 3836                 1  On-site                         Giza Systems
# 3835                 1  On-site                       Orchidiapharma
# 3829                 1   Remote                           Talent 360
# 3828                 1  On-site                           Talent 360
# 3821                 1  On-site                 Decima International
# 3820                 1  On-site          Delta Research Spain S.L.U.
#
#                  city        type  \
# 4007          Unknown     Unknown
# 2675          Unknown     Unknown
# 4005          القاهرة     Unknown
# 4004          القاهرة  Management
# 4003  العلمين الجديدة     Unknown
# 4002          Unknown     Unknown
# 4001          القاهرة     Unknown
# 4000          القاهرة     Unknown
# 3822          Unknown     Unknown
# 3836          القاهرة     Unknown
# 3835          القاهرة     Unknown
# 3829          القاهرة     Unknown
# 3828          القاهرة     Unknown
# 3821          القاهرة     Unknown
# 3820          القاهرة   Full-Time
#
#                                               industry_      company_size  \
# 4007                         خدمات الدعم التجاري الأخرى           Unknown
# 2675                         خدمات الدعم التجاري الأخرى           Unknown
# 4005                         خدمات الدعم التجاري الأخرى           Unknown
# 4004                         خدمات الدعم التجاري الأخرى           Unknown
# 4003                                     الضيافة والسكن  500 موظف أو أكثر
# 4002                         الاستشارات الهندسية العامة           Unknown
# 4001                         خدمات الدعم التجاري الأخرى  500 موظف أو أكثر
# 4000                         خدمات الدعم التجاري الأخرى           Unknown
# 3822                         خدمات الدعم التجاري الأخرى           Unknown
# 3836                                            Unknown           Unknown
# 3835                         خدمات الدعم التجاري الأخرى           Unknown
# 3829                         خدمات الدعم التجاري الأخرى           Unknown
# 3828                         خدمات الدعم التجاري الأخرى           Unknown
# 3821                                خدمات الدعم الإداري           Unknown
# 3820  الاستعانة بالمصادر الخارجية لخدمة العملاء - ال...      100-499 موظف
#
#      min_num_of_years max_num_of_years         gender      job_level
# 4007          Unknown          Unknown  No Preference  No Preference
# 2675          Unknown          Unknown  No Preference  No Preference
# 4005          Unknown          Unknown           Male  No Preference
# 4004          Unknown          Unknown  No Preference     Management
# 4003          Unknown          Unknown  No Preference  No Preference
# 4002          Unknown          Unknown  No Preference  No Preference
# 4001          Unknown          Unknown  No Preference  No Preference
# 4000          Unknown          Unknown  No Preference  No Preference
# 3822          Unknown          Unknown  No Preference  No Preference
# 3836          Unknown          Unknown  No Preference  No Preference
# 3835          Unknown          Unknown  No Preference  No Preference
# 3829          Unknown          Unknown  No Preference  No Preference
# 3828          Unknown          Unknown  No Preference  No Preference
# 3821          Unknown          Unknown  No Preference  No Preference
# 3820          Unknown          Unknown           Male  No Preference

# %% [markdown]
# ### Job Title Cleaning Process
# 1. **Pattern Replacement**:
#    - Applied a regular expression pattern to remove unwanted terms like "sr", "ssr", "senior", "junior", "staff", gender-related terms (e.g., "male", "female"), and specific job rank indicators (e.g., "trainee", "graduate").
#    - Cleaned up job titles to ensure they follow the correct format without extra symbols, spaces, or unnecessary words.
# 2. **Title Editing**:
#    - Applied a predefined title mapping (`edite_title_mapping`) to standardize job titles, ensuring consistency across the dataset (e.g., "cashier" becomes "cashier", "driller" becomes "drilling operator").
# 3. **Save the Data**:
#    - The cleaned titles were saved back into the database for further analysis, ensuring all records follow the standardized format.

# %%
final_mapping_title_egypt = {
    r'3d designer': '3d designer',
    r'^account director': 'account director',
    r'account executive': 'account executive',
    r'account management': 'account management',
    r'(?=.*(account))(?=.*(receivable))': 'account receivable',
    r'ai engineer\b': 'ai engineer',
    r'^ai$': 'ai engineer',
    r'(?=.*(account))(?=.*(manage))^(?!.*(?:sale|hr\b|humanresources|humansresources|human\s*resources|humans\s*resources|market|trade)).*': 'account manager',
    r'^account payable accountant.*': 'account payable accountant',
    r'^account receivable.*': 'account receivable',
    r'^accounting (& financial|& reporting|manager).*': 'accounting manager',
    r'^accounting (section|supervisor|team|assistant|advisory).*': 'accounting supervisor',
    r'^accounting intern.*?': 'accountant',
    r'^accounts payable.*': 'accounts payable',
    r'^accounts receivable.*': 'accounts receivable',
    r'^accounts supervisor.*': 'accounts receivable supervisor',
    r'^accountant.*(?!.*(?:receivable))': 'accountant',
    r'^tax accountant.*': 'accountant',
    r'^tax & legal.*': 'accountant',
    r'(?=.*(operations|operation))(?=.*(manager|senior manager|area manager))(?=.*(ad|campaign))': 'ad operations manager',
    r'(?=.*(admin))(?=.*(assistant))': 'account assistant',
    r'administrative assistant': 'administrative assistant',
    r'ai product manager': 'ai product manager',
    r'(?=.*(machine learning|ml|machinelearning))(?=.*(engineer))^(?!.*(?:mlops|ops)).*': 'ai/ml engineer',
    r'^analyst': 'analyst',
    r'application specialist': 'application specialist',
    r'architectural engineer': 'architectural engineer',
    r'(?=.*engineer)(?=.*architectur)': 'architectural engineer',
    r'architecture (- co-op trainee|engineer)': 'architecture engineer',
    r'area manager': 'area manager',
    r'art director': 'art director',
    r'assistant director': 'assistant director',
    r'assistant manager': 'assistant manager',
    r'assistant project manager': 'assistant project manager',
    r'assurance - external audit(?!.*manager)': 'assurance - external audit',
    r'(?=.*(operations|operation))(?=.*(specialist|coordinator|associate))(?=.*(audit))': 'audit operations specialist',
    r'area sales manager': 'area sales manager',
    r'area sales engineer': 'area sales engineer',
    r'area security manager': 'area security engineer',
    r'automation testing engineer': 'automation testing engineer',
    r'associate customer success manager': 'associate customer success manager',
    r'assistant sales manager': 'assistant sales manager',
    r'ar accountant': 'accountant',
    r'arabic english interpreter': 'arabic english interpreter',
    # -------------------------------------------------------------------------
    r'backend developer': 'backend developer',
    r'(?=.*(developer))(?=.*backend)^(?!.*(?:lead|manager|test automation)).*': 'backend developer',
    r'^web developer$': 'fullstack developer',
    r'(?=.*(web developer))^(?!.*(?:full stack)).*': 'backend developer',
    r'^barista': 'barista',
    r'(?=.*(bim))(?=.*(structur))': 'bim structure engineer',
    r'(?<!associate )business analyst': 'business analyst',
    r'^business development(\\s-|$)': 'business development',
    r'business development executive': 'business development executive',
    r'business development lead': 'business development lead',
    r'(business development [a-z]+ manager)|(business development manager)|(manager .* business development)': 'business development manager',
    r'business development representative': 'business development representative',
    r'(business development specialist)|(specialist .* business development)': 'business development specialist',
    r'^business support(?!.*manager)': 'business support',
    r'brand manager': 'brand manager',
    r'(?=.*(development))(?=.*(business))^(?!.*(?:manager|lead|office|director|executive|representative|specialist|associate)).*': 'business development',
    r'(?=.*(intelligence))(?=.*(engineer))(?=.*(business))': 'business intelligence engineer',
    r'(?=.*(research))(?=.*(business))^(?!.*(?:manager|lead)).*': 'business research',
    r'(?=.*(research))(?=.*(business))^(?=.*(manager))': 'business research manager',
    r'(?=.*(research))(?=.*(business))^(?=.*(lead))': 'business research lead',
    # -------------------------------------------------------------------------
    r'(?=.*(call))(?=.*(center))^(?!.*(?:manager|lead)).*': 'call center agent',
    r'(?=.*(call))(?=.*(center))^(?=.*(lead))': 'call center lead',
    r'(?=.*(call))(?=.*(center|centre))^(?=.*(manager))': 'call center manager',
    r'cashier': 'cashier',
    r'category manager': 'category manager',
    r'(?=.*(ceo))': 'ceo assistant',
    r'^(?!.*demi).*chef de partie': 'chef de partie',
    r'(?=.*(chief))(?=.*(accountant))': 'chief accountant',
    r'chief concierge': 'chief concierge',
    r'^(?!.*assistant).*chief engineer': 'chief engineer',
    r'civil 3d': 'civil 3d',
    r'(?=.*engineer)(?=.*civil)^(?!.*(?:mechanical|manager|structure)).*': 'civil engineer',
    r'client partner manager': 'client partner manager',
    r'cluster director': 'cluster director',
    r'commercial manager': 'commercial manager',
    r'commi( |s |s$)': 'commis',
    r'compliance manager': 'compliance manager',
    r'^(?!.*(?:chief|trade|payroll|tax)).*compliance officer': 'compliance officer',
    r'^(?!.*(?:manager|senior)).*^consulting': 'consulting',
    r'^consulting.*senior manager': 'consulting senior manager',
    r'content (creator|maker)': 'content creator',
    r'content (writer|researcher)': 'content writer',
    r'^contract(s)? specialist': 'contract specialist',
    r'contract(s)? engineer': 'contracts engineer',
    r'controls engineer': 'controls engineer',
    r'^coordinator': 'coordinator',
    r'copywriter': 'copywriter',
    r'^cost control engineer': 'cost control engineer',
    r'^counsel': 'counsel',
    r'(?=.*(operations|operation))(?=.*(manager|senior manager|area manager))(?=.*(customer))': 'customer operations manager',
    r'customer service executive': 'customer service executive',
    r'(?=.*(operations|operation))(?=.*(specialist|coordinator|associate))(?=.*(lost\\s+and\\s+found))': 'customer service specialist',
    r'cyber security': 'cyber security',
    'captian': 'captain',
    'center quality manager': 'center quality manager',
    'channel management': 'channel management',
    '^consultant.*': 'consultant',
    r'^(consulting)(?!.*(?:manager|quality|lead)).*': 'consultant',
    r'^(?=.*(content))(?=.*(specialist))^(?!.*(?:marketing|photo)).*': 'content specialist',
    r'(?=.*(customer))(?=.*(representative))': 'customer representative',
    r'(?=.*(customer))(?=.*(service))': 'customer service',
    r'(?=.*(customer))(?=.*(support))(?=.*(specialist))': 'customer support specialist',
    r'(?=.*(customer))(?=.*(experience))(?=.*(specialist))': 'customer experience specialist',

    r'^data center': 'data center engineer',
    r'(?=.*(data))(?=.*(analy))^(?!.*(?:manager|quality|lead)).*': 'data analyst',
    r'database expert': 'database engineer',
    r'^data engineer': 'data engineer',
    r'(?=.*(operations|operation))(?=.*(specialist|coordinator|associate))(?=.*(data|collection))': 'data operations specialist',
    r'data scientist': 'data scientist',
    r'^team lead data scientist': 'data scientist lead',
    r'demi chef de partie': 'demi chef de partie',
    r'^design engineer': 'design engineer',
    r'^design manager': 'design manager',
    r'^developer': 'developer',
    r'^(?!.*(?:lead)).*^devops engineer': 'devops engineer',
    r'(?=.*(engineer))(?=.*(devops))(?=.*(operations|operation))': 'devops operations engineer ',
    r'^director .*(finance|faas)': 'director – finance',
    r'^document controller': 'document controller',
    r'data integrat': 'data integration developer',
    r'(?=.*(data))(?=.*(management))(?=.*(consultant))': 'data management consultant',
    r'(?=.*(data))(?=.*(quality))': 'data quality analyst',
    r'(?=.*(data))(?=.*(scien))^(?!.*(?:manager|director)).*': 'data scientist',
    r'demi coding instructor physical': 'demi coding instructor physical',
    r'(?=.*(digital))(?=.*(marketing))(?=.*(specialist))': 'digital marketing specialist',
    'draftsman': 'draftsman',
    # -------------------------------------------------------------------------
    r'(?=.*(operations|operation))(?=.*(manager|senior manager|area manager))(?=.*(ecommerce|b2b))': 'ecommerce operations manager',
    r'(?=.*(electrical))(?=.*(design))(?=.*(engineer))': 'electrical design engineer',
    r'(?=.*(electrical))(?=.*(engineer))^(?!.*(?:lead|design|support|office|maintenance)).*': 'electrical design engineer',
    r'(?i)(?=.*\\b(?:electrical)\\b).*\\boffice engineer\\b.*': 'electrical office engineer',
    r'(?=.*(electrical))(?=.*(technical))(?=.*(office))(?=.*(engineer))': 'electrical technical office engineer',
    r'energy analyst': 'energy analyst',
    r'(?=.*engineer)(?=.*manager)^(?!.*(?:department|and|data|neighborhoods|mechanical|design|interface|cloud|area|divisional|project|software|technical|solution|&|sales|fire)).*': 'engineer manager',
    r'(?=.*engineer)(?=.*planning)^(?!.*(?:strategic|and|master|maintenance|electrical|lead)).*': 'engineer planning',
    r'(?<!ai )engineering manager': 'engineering manager',
    r'(?=.*estimator)': 'estimator',
    r'(?=.*execution)(?=.*manager)': 'execution manager',
    r'(?=.*e-commerce)(?=.*manager)': 'e-commerce manager',
    r'(?=.*executive)(?=.*assistan)^(?!.*(?:manager|front|and)).*': 'executive assistant',
    r'(?=.*executive)(?=.*chef)^(?!.*(?:pastry|sous)).*': 'executive chef',
    r'(?=.*expeditor)': 'expeditor',
    r'engineer \(r\&d\)': 'engineer',
    # -------------------------------------------------------------------------
    r'(?=.*finance controller)': 'finance controller',
    r'(?=.*^finance)(?=.*manager)': 'finance manager',
    r'(?=.*(operations|operation))(?=.*(manager|senior manager|area manager))(?=.*(finance))': 'finance operations manager',
    r'(?<!lead )financial analyst': 'financial analyst',
    r'(?=.*front)(?=.*office)(?=.*agent)': 'front office agent',
    r'(?=.*front)(?=.*office)(?=.*manager)': 'front office manager',
    r'(?=.*(developer))(?=.*(frontend|front end|front\-end))^(?!.*(?:lead|manager|test automation)).*': 'frontend developer',
    r'(?=.*(developer))(?=.*(fullstack|full stack|full\-stack))^(?!.*(?:lead|manager|test automation)).*': 'fullstack developer',
    r'(?=.*(web developer))^(?!.*(?:php)).*': 'fullstack developer',
    r'(?=.*(developer))(?=.*((fullstack|full stack|full\-stack)|full stack))(?=.*lead)': 'fullstack developer lead',
    r'(?=.*(engineer))(?=.*(fullstack|full stack|full\-stack))(?=.*lead)': 'fullstack engineer lead',
    r'finance director': 'finance director',
    r'data collector': 'data collector',
    r'(?=.*(finance))(?=.*(account))^(?!.*(?:manager)).*': 'finance account',
    r'(?=.*(financ))(?=.*(controller))': 'finance controller',
    r'(?=.*(financ))(?=.*(planning))(?=.*(analysis))^(?!.*(?:head)).*': 'finance planning analysis manager',
    r'first mile hub supervisor': 'first mile hub supervisor',
    r'food and beverage manager': 'food and beverage manager',
    r'fp&a analyst': 'fp&a analyst',
    r'(?=.*(front))(?=.*(desk))^(?!.*(?:manager|officer|supervisor|clerk|receptionist)).*': 'front desk agent',
    # -------------------------------------------------------------------------
    r'(?=.*government)(?=.*(relation))(?=.*officer)^(?!.*&).*': 'government relation officer',
    r'(?=.*graphic)(?=.*(design))^(?!.*(?:and|manager|concept|specialist)).*': 'graphic design',
    r'(?=.*guest)(?=.*(experience))(?=.*agent)': 'guest experience agent',
    r'general accountant': 'general accountant',
    r'global procurement associate analyst': 'global procurement associate analyst',
    # -------------------------------------------------------------------------
    r'(?=.*(hr))(?=.*(account\\s+manager))': 'hr account manager',
    r'(?=.*(hr\b|humanresources|humansresources|human\s*resources|humans\s*resources))(?=.*(specialist))(?=.*(admin|payroll))': 'hr admin & payroll specialist',
    r'(?=.*(hr\b|humanresources|humansresources|human\s*resources|humans\s*resources))(?=.*(analyst))': 'hr analyst',
    r'(?=.*(hr\b|humanresources|humansresources|human\s*resources|humans\s*resources))(?=.*(business\\s*partner))': 'hr business partner',
    r'(?=.*(hr))(?=.*(service\\s+delivery))(?=.*(compensation|benefit))': 'hr compensation & benefits associate',
    r'(?=.*(hr))(?=.*(coordinator))': 'hr coordinator',
    r'(?=.*(director))(?=.*(human\\s*resources))^(?!.*(?:assistant)).*': 'hr director',
    r'(?=.*(hr))(?=.*(employer\\s+branding|marketing))': 'hr employer branding specialist',
    r'(?=.*(hr\b|humanresources|humansresources|human\s*resources|humans\s*resources))(?=.*(generalist))': 'hr generalist',
    r'(?=.*(head))(?=.*(hr\b|humanresources|humansresources|human\s*resources|humans\s*resources))': 'hr head',
    r'(?=.*(hr\b|humanresources|humansresources|human\s*resources|humans\s*resources))(?=.*(intern|graduate))': 'hr intern',
    r'(?=.*(hr\b|humanresources|humansresources|human\s*resources|humans\s*resources))(?=.*(lead))': 'hr lead',
    r'(?=.*(hr\b|humanresources|humansresources|human\s*resources|humans\s*resources))(?=.*(manager))': 'hr manager',
    r'(?=.*(hr\b|humanresources|humansresources|human\s*resources|humans\s*resources))(?=.*(officer|executive))': 'hr officer',
    r'(?=.*(hr\b|humanresources|humansresources|human\s*resources|humans\s*resources))(?=.*(specialist))(?=.*(resourcing|recruitment))': 'hr recruitment specialist',
    r'(?=.*(operations|operation))(?=.*(specialist|coordinator|associate))(?=.*(people|hr))': 'hr specialist',
    r'(?=.*(hr\b|humanresources|humansresources|human\s*resources|humans\s*resources))(?=.*(specialist))': 'hr specialist',
    r'(?=.*(hr))(?=.*(application|process|pmo))': 'hr systems/process specialist',
    r'(?=.*(hr))(?=.*(partner))(?=.*(talent|performance))': 'hr talent partner',
    r'(?=.*(hub))(?=.*(operations))(?=.*(coordinator))^(?!.*(?:section head|manager)).*': 'hub operations coordinator',
    r'a427-esg': 'hvac technician',
    # -------------------------------------------------------------------------
    r'(?=.*(information))(?=.*(security))^(?!.*(?:section head|manager)).*': 'information security',
    r'(?=.*(integration))(?=.*(developer))': 'integration developer',
    r'(?=.*(interior))(?=.*(designer))': 'interior designer',
    r'(?=.*(design))(?=.*(interior))^(?!.*(?:manager)).*': 'interior designer',
    r'(?=.*(audit))(?=.*(internal))': 'internal auditor',
    r'(?=.*(operations|operation))(?=.*(manager|senior manager|area manager))(?=.*(technology|it))': 'it operations manager',
    r'it operations': 'it support',
    # -------------------------------------------------------------------------
    r'(?=.*(java))(?=.*(developer))': 'java developer',
    r'(?=.*(java))(?=.*(engineer))': 'java engineer',
    # -------------------------------------------------------------------------
    r'7pqe\\+ dispute resolution associate': 'legal counsel',
    r'(?=.*(logistics))(?=.*(coordinator))^(?!.*(?:section head|manager)).*': 'logistics coordinator',
    r'(?=.*(logistics))(?=.*(coordintor|coordinatoor|coordinator))': 'logistics coordinator',
    # -------------------------------------------------------------------------
    r'maintenance technician': 'maintenance technician',
    r'marketing manager': 'marketing manager',
    r'(?=.*(marketing))(?=.*(manager))': 'marketing manager',
    r'(?=.*engineer)(?=.*mechanical)^(?!.*(?:electrical|manager|design|reliability|civil|maintenance|lead)).*': 'mechanical engineer',
    r'(?=.*engineer)(?=.*mechanical)^(?!.*(?:manager|design|reliability|civil|maintenance|lead)).*': 'mechanical engineer',
    r'(?i)(?=.*\\b(?:mechanical)\\b).*\\boffice engineer\\b.*': 'mechanical office engineer',
    r'(?=.*(medical))(?=.*(assistant))^(?!.*(?:manager|design|reliability|civil|maintenance|lead)).*': 'media assistant',
    r'(?=.*(medical))(?=.*(assistant))': 'media assistant lead',
    r'(?=.*(media))(?=.*(buyer))^(?!.*(?:manager|design|reliability|civil|maintenance|lead)).*': 'media buyer',
    r'(?=.*(media))(?=.*(buyer|buying))(?=.*(lead))': 'media buyer lead',
    r'medical representative': 'medical representative',
    r'(?=.*(operations|operation))(?=.*(manager|senior manager|area manager))(?=.*(merchant|vendor))': 'merchant operations manager',
    r'(?=.*(developer))(?=.*(mobile|ios|android|flutter))^(?!.*(?:lead|manager|test automation)).*': 'mobile developer',
    r'(?=.*(developer))(?=.*mobile)(?=.*lead)': 'mobile developer lead',
    r'(?=.*(developer))(?=.*mobile)(?=.*manager)': 'mobile developer manager',
    r'(?=.*(developer))(?=.*mobile)(?=.*test automation)': 'mobile developer test automation',
    r'(?=.*(engineer))(?=.*mobile)(?=.*lead)': 'mobile engineer lead',
    r'(?=.*(engineer))(?=.*mobile)(?=.*manager)': 'mobile engineer manager',
    r'(?=.*(engineer))(?=.*mobile)(?=.*test automation)': 'mobile engineer test automation',
    # -------------------------------------------------------------------------
    r'odoo developer': 'odoo developer',
    r'^(?!.*\\b(architecture|electrical|mechanical)\\b).*office engineer.*': 'office engineer',
    r'(?=.*(manager))(?=.*(office))^(?!.*(?:assistant)).*': 'office manager',
    r'^(?!.*\\b(cyber security|cybersecurity|devops)\\b).*operations engineer.*': 'operations engineer',
    r'(?=.*(engineer))(?=.*(operations|operation))^(?!.*(?:devops)).*': 'operations engineer',
    r'(?=.*(operations|operation))(?=.*(manager|senior manager|area manager))^(?!.*(sales|strategic|data|lost|live|hardware|hub|finance|financial|mall|retail|product|strategy|planning|technology|it|security|soc|merchant|customer|ad|ecommerce|b2b|gym|fitness|procurement)).*': 'operations manager',
    r'(?=.*(operations|operation))(?=.*(specialist|coordinator|associate))^(?!.*(sales|strategic|data|lost|live|hardware|hub|finance|financial|mall|retail|product|strategy|planning|technology|it|security|soc|merchant|customer|ad|ecommerce|b2b|gym|fitness|procurement)).*': 'operations specialist',
    r'data collection': 'operations specialist data collection',
    # -------------------------------------------------------------------------
    r'people operations specialist': 'people operations specialist',
    r'(?=.*(personal))(?=.*(assistant))': 'personal assistant',
    r'(?=.*(personal))(?=.*(banker))^(?!.*(?:payroll)).*': 'personal banker',
    r'(?=.*(pharmacist))': 'pharmacist',
    r'(?=.*(operations|operation))(?=.*(manager|senior manager|area manager))(?=.*(procurement))': 'procurement operations manager',
    r'product designer': 'product designer',
    r'(?<!ai )product manager': 'product manager',
    r'(?=.*(operations|operation))(?=.*(manager|senior manager|area manager))(?=.*(product))': 'product operations manager',
    r'product owner (vois)': 'product owner',
    r'project manager (architect or civil engineer)': 'project manager engineer',
    r'(?=.*(purchase|purchasing))(?=.*(specialist))': 'purchasing specialist',
    # -------------------------------------------------------------------------
    r'qa engineer': 'qa engineer',
    r'quality engineer': 'quality engineer',
    # -------------------------------------------------------------------------
    r'(?=.*(operations|operation))(?=.*(manager|senior manager|area manager))(?=.*(retail))': 'retail operations manager',
    # -------------------------------------------------------------------------
    r'sales and business development manager': 'sales & business development manager',
    r'sales account manager': 'sales account manager',
    r'sales assistant(?!.*analyst)': 'sales assistant',
    r'sales development representative': 'sales development representative',
    r'sales director': 'sales director',
    r'sales executive': 'sales executive',
    r'(?<!assistant )sales manager': 'sales manager',
    r'sales manager / account manager': 'sales manager / account manager',
    r'(?=.*(operations|operation))(?=.*(specialist|coordinator|associate))(?=.*(sales))': 'sales operations specialist',
    r'(?=.*(sales))(?=.*(support))(?=.*(specialist))': 'sales operations specialist',
    r'scrum master smart village,cairo,egypt + 1 more product development posted 14 hours ago': 'scrum master',
    r'security engineer': 'security engineer',
    r'service manager': 'service manager',
    r'(?=.*(operations|operation))(?=.*(manager|senior manager|area manager))(?=.*(security|soc))': 'soc manager',
    r'social media moderator*': 'social media moderator',
    r'(?!.*\\b(backend|frontend|front end|front\-end|mobile|lead|.net)\\b).*^software engineer.*': 'software engineer',
    r'(?=.*(engineer|engineering))(?=.*backend)^(?!.*(?:lead|manager|test automation)).*': 'software engineer backend',
    r'(?=.*software)(?=.*(engineer|engineering))(?=.*backend)^(?!.*(?:lead|manager|test automation)).*': 'software engineer backend',
    r'(?=.*software)(?=.*(engineer|engineering))(?=.*backend)(?=.*lead)': 'software backend engineer  lead',
    r'(?=.*software)(?=.*(engineer|engineering))(?=.*(frontend|front end|front\-end))': 'software frontend engineer',
    r'(?=.*(engineer|engineering))(?=.*frontend)': 'software frontend engineer',
    r'(?=.*(engineer|engineering))(?=.*(fullstack|full stack|full\-stack))^(?!.*(?:lead|manager|test automation)).*': 'software engineer fullstack',
    r'(?=.*software)(?=.*(engineer|engineering))(?=.*(fullstack|full stack|full\-stack))^(?!.*(?:lead|manager|test automation)).*': 'software engineer fullstack',
    r'(?=.*software)(?=.*(engineer|engineering))(?=.*(mobile|ios|android|flutter))': 'software mobile engineer',
    r'(?=.*(engineer|engineering))(?=.*(mobile|ios|android|flutter))': 'software mobile engineer',
    r'store manager.*': 'store manager',
    r'(?=.*(operations|operation))(?=.*(manager|senior manager|area manager))(?=.*(strategy|planning))': 'strategy & operations manager',
    r'^(?!.*manager).*supply (chain|planning|demand|analyst).*': 'supply chain analyst',
    r'supply chain executive': 'supply chain lead',
    r'(?i)(?=.*\\b(?:(manager|management))\\b).*\\bsupply (chain|planning|demand|analyst).*': 'supply chain manager',
    r'technical support': 'support engineer',
    r'support engineer': 'support engineer',
    r'technical support &': 'support manager',
    r'system administrator.*': 'system administrator',
    r'system(s)? engineer.*': 'system engineer',
    r'(?=.*(Account))(?=.*(Manager))(?=.*(Sale))': 'Sales Account Manager',
    # -------------------------------------------------------------------------
    r'^talent acquisition .*(manager|head).*': 'talent acquisition manager',
    r'talent acquisition (specialist|partner|&).*': 'talent acquisition specialist',
    r'^talent acquisition and learning and development specialist': 'talent acquisition specialist',
    r'^technical consulting.*': 'technical consulting',
    r'(?!.*\\b(java|(ai/ml)|.net)\\b).*^(technical|tech) lead.*': 'technical lead',
    r'(technical|tech) lead': 'technical lead',
    r'testing engineer|tester': 'testing engineer',
    r'software tester': 'testing engineer',
    r'training manager': 'training manager',
    r'^treasury senior accountant': 'treasury accountant',
    r'^treasury (section|head).*': 'treasury lead',
    r'^treasurer$': 'treasury specialist',
    r'^treasur(y|er)\\s?(specialist|senior specialist|and| - emea).*': 'treasury specialist',
    # -------------------------------------------------------------------------
    r'(?=.*(designer))(?=.*(ux/ui|ui/ux|ux|ui))': 'ux/ui designer',
    r'(?=.*(developer))(?=.*(ux/ui|ui/ux|ux|ui))': 'ux/ui developer',
    # -------------------------------------------------------------------------
}
df_egypt.title.value_counts()
# Out:
# title
# accountant                                         83
# business analyst                                   65
# account manager                                    62
# support engineer                                   41
# graphic design                                     38
#                                                    ..
# wealth management relationship manager              1
# water treatment chemicals senior sales engineer     1
# warehouses manager                                  1
# warehouse operations supervisor                     1
# warehouse keeper                                    1
# Name: count, Length: 2025, dtype: int64

# %%
pattern_replace = r'(^((sr(\b|\s)|\ssr(\b|\s))|senior|junior|staff|female|\bmen\b|\bmale\b|women(\'s)|tpe (iv|iii|ii|i|v)(\s)?(-|/)?)( (senior|graduate))?|^graduate|^trainee\b( -)?)(\s)?(\.|-|/|\\)?|(\.|\-|/|\,|\\)$'
df_egypt.title = df_egypt.title.str.replace(pattern_replace, '', regex=True).str.strip()
df_egypt = df_egypt.sort_values(by="title", ascending=False, key=lambda col: col.str.lower()).reset_index(drop=True)

# %%
review_matches(df_egypt, final_mapping_title_egypt)
# Out:
# ------------------------------------------------------3d designer-------------------------------------------------------
# 4007    3d designer
# 4008    3d designer
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------------------------^account director----------------------------------------------------
# 3981    account director
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------------------------account executive----------------------------------------------------
# 3972    account executive
# 3973    account executive
# 3974    account executive
# 3975    account executive
# 3976    account executive
# 3977    account executive
# 3978    account executive
# 3979    account executive
# 3980    account executive
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------------------------account management---------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# -------------------------------------------(?=.*(account))(?=.*(receivable))--------------------------------------------
# 3890    account receivable
# 3891    account receivable
# 3892    account receivable
# 3893    account receivable
# 3894    account receivable
# 3895    account receivable
# 3896    account receivable
# 3897    account receivable
# 3898    account receivable
# 3899    account receivable
# 3900    account receivable
# 3901    account receivable
# 3902    account receivable
# 3903    account receivable
# Name: title, dtype: object
# ########################################################################################################################
# -----------------------------------------------------ai engineer\b------------------------------------------------------
# 3755    ai engineer
# 3756    ai engineer
# 3757    ai engineer
# 3758    ai engineer
# Name: title, dtype: object
# ########################################################################################################################
# ----------------------------------------------------------^ai$----------------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# (?=.*(account))(?=.*(manage))^(?!.*(?:sale|hr\b|humanresources|humansresources|human\s*resources|humans\s*resources|market|trade)).*
# 3805    accounting manager
# 3910       account manager
# 3911       account manager
# 3912       account manager
# 3913       account manager
# 3914       account manager
# 3915       account manager
# 3916       account manager
# 3917       account manager
# 3918       account manager
# 3919       account manager
# 3920       account manager
# 3921       account manager
# 3922       account manager
# 3923       account manager
# 3924       account manager
# 3925       account manager
# 3926       account manager
# 3927       account manager
# 3928       account manager
# 3929       account manager
# 3930       account manager
# 3931       account manager
# 3932       account manager
# 3933       account manager
# 3934       account manager
# 3935       account manager
# 3936       account manager
# 3937       account manager
# 3938       account manager
# 3939       account manager
# 3940       account manager
# 3941       account manager
# 3942       account manager
# 3943       account manager
# 3944       account manager
# 3945       account manager
# 3946       account manager
# 3947       account manager
# 3948       account manager
# 3949       account manager
# 3950       account manager
# 3951       account manager
# 3952       account manager
# 3953       account manager
# 3954       account manager
# 3955       account manager
# 3956       account manager
# 3957       account manager
# 3958       account manager
# 3959       account manager
# 3960       account manager
# 3961       account manager
# 3962       account manager
# 3963       account manager
# 3964       account manager
# 3965       account manager
# 3966       account manager
# 3967       account manager
# 3968       account manager
# 3969       account manager
# 3970       account manager
# 3971       account manager
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------------------^account payable accountant.*----------------------------------------------
# 3904    account payable accountant
# 3905    account payable accountant
# 3906    account payable accountant
# 3907    account payable accountant
# 3908    account payable accountant
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------------------------------^account receivable.*--------------------------------------------------
# 3890    account receivable
# 3891    account receivable
# 3892    account receivable
# 3893    account receivable
# 3894    account receivable
# 3895    account receivable
# 3896    account receivable
# 3897    account receivable
# 3898    account receivable
# 3899    account receivable
# 3900    account receivable
# 3901    account receivable
# 3902    account receivable
# 3903    account receivable
# Name: title, dtype: object
# ########################################################################################################################
# ------------------------------------^accounting (& financial|& reporting|manager).*-------------------------------------
# 3805    accounting manager
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------------^accounting (section|supervisor|team|assistant|advisory).*-------------------------------
# 3793    accounting supervisor
# 3794    accounting supervisor
# 3795    accounting supervisor
# 3796    accounting supervisor
# 3797    accounting supervisor
# 3798    accounting supervisor
# 3799    accounting supervisor
# 3800    accounting supervisor
# 3801    accounting supervisor
# 3802    accounting supervisor
# 3803    accounting supervisor
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------------------------------^accounting intern.*?--------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# --------------------------------------------------^accounts payable.*---------------------------------------------------
# 3784    accounts payable
# 3785    accounts payable
# 3786    accounts payable
# 3787    accounts payable
# 3788    accounts payable
# 3789    accounts payable
# 3790    accounts payable
# 3791    accounts payable
# 3792    accounts payable
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------------------------------^accounts receivable.*-------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# -------------------------------------------------^accounts supervisor.*-------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# -------------------------------------------^accountant.*(?!.*(?:receivable))--------------------------------------------
# 3806    accountant
# 3807    accountant
# 3808    accountant
# 3809    accountant
# 3810    accountant
# 3811    accountant
# 3812    accountant
# 3813    accountant
# 3814    accountant
# 3815    accountant
# 3816    accountant
# 3817    accountant
# 3818    accountant
# 3819    accountant
# 3820    accountant
# 3821    accountant
# 3822    accountant
# 3823    accountant
# 3824    accountant
# 3825    accountant
# 3826    accountant
# 3827    accountant
# 3828    accountant
# 3829    accountant
# 3830    accountant
# 3831    accountant
# 3832    accountant
# 3833    accountant
# 3834    accountant
# 3835    accountant
# 3836    accountant
# 3837    accountant
# 3838    accountant
# 3839    accountant
# 3840    accountant
# 3841    accountant
# 3842    accountant
# 3843    accountant
# 3844    accountant
# 3845    accountant
# 3846    accountant
# 3847    accountant
# 3848    accountant
# 3849    accountant
# 3850    accountant
# 3851    accountant
# 3852    accountant
# 3853    accountant
# 3854    accountant
# 3855    accountant
# 3856    accountant
# 3857    accountant
# 3858    accountant
# 3859    accountant
# 3860    accountant
# 3861    accountant
# 3862    accountant
# 3863    accountant
# 3864    accountant
# 3865    accountant
# 3866    accountant
# 3867    accountant
# 3868    accountant
# 3869    accountant
# 3870    accountant
# 3871    accountant
# 3872    accountant
# 3873    accountant
# 3874    accountant
# 3875    accountant
# 3876    accountant
# 3877    accountant
# 3878    accountant
# 3879    accountant
# 3880    accountant
# 3881    accountant
# 3882    accountant
# 3883    accountant
# 3884    accountant
# 3885    accountant
# 3886    accountant
# 3887    accountant
# 3888    accountant
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------------------------^tax accountant.*----------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# -----------------------------------------------------^tax & legal.*-----------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# ---------------(?=.*(operations|operation))(?=.*(manager|senior manager|area manager))(?=.*(ad|campaign))---------------
# 3779    ad operations manager
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------------------(?=.*(admin))(?=.*(assistant))---------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# ------------------------------------------------administrative assistant------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# ---------------------------------------------------ai product manager---------------------------------------------------
# 3753    ai product manager
# Name: title, dtype: object
# ########################################################################################################################
# -------------------(?=.*(machine learning|ml|machinelearning))(?=.*(engineer))^(?!.*(?:mlops|ops)).*--------------------
# 3739    ai/ml engineer
# 3740    ai/ml engineer
# 3741    ai/ml engineer
# 3742    ai/ml engineer
# 3743    ai/ml engineer
# 3744    ai/ml engineer
# 3745    ai/ml engineer
# 3746    ai/ml engineer
# 3747    ai/ml engineer
# 3748    ai/ml engineer
# 3749    ai/ml engineer
# 3750    ai/ml engineer
# 3751    ai/ml engineer
# 3752    ai/ml engineer
# Name: title, dtype: object
# ########################################################################################################################
# --------------------------------------------------------^analyst--------------------------------------------------------
# 3720    analyst
# 3721    analyst
# 3722    analyst
# 3723    analyst
# 3724    analyst
# 3725    analyst
# 3726    analyst
# 3727    analyst
# 3728    analyst
# 3729    analyst
# 3730    analyst
# 3731    analyst
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------------------------------application specialist-------------------------------------------------
# 3701    application specialist
# 3702    application specialist
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------------------------------architectural engineer-------------------------------------------------
# 3673    architectural engineer
# 3674    architectural engineer
# 3675    architectural engineer
# 3676    architectural engineer
# 3677    architectural engineer
# 3678    architectural engineer
# 3679    architectural engineer
# 3680    architectural engineer
# 3681    architectural engineer
# 3682    architectural engineer
# 3683    architectural engineer
# 3684    architectural engineer
# Name: title, dtype: object
# ########################################################################################################################
# --------------------------------------------(?=.*engineer)(?=.*architectur)---------------------------------------------
# 3673    architectural engineer
# 3674    architectural engineer
# 3675    architectural engineer
# 3676    architectural engineer
# 3677    architectural engineer
# 3678    architectural engineer
# 3679    architectural engineer
# 3680    architectural engineer
# 3681    architectural engineer
# 3682    architectural engineer
# 3683    architectural engineer
# 3684    architectural engineer
# Name: title, dtype: object
# ########################################################################################################################
# ----------------------------------------architecture (- co-op trainee|engineer)-----------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# ------------------------------------------------------area manager------------------------------------------------------
# 3670    area manager
# Name: title, dtype: object
# ########################################################################################################################
# ------------------------------------------------------art director------------------------------------------------------
# 3664    art director
# 3665    art director
# 3666    art director
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------------------------assistant director---------------------------------------------------
# 3651    assistant director
# 3652    assistant director
# 3653    assistant director
# 3654    assistant director
# 3655    assistant director
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------------------------assistant manager----------------------------------------------------
# 3637    assistant manager
# 3638    assistant manager
# 3639    assistant manager
# 3640    assistant manager
# 3641    assistant manager
# 3642    assistant manager
# 3643    assistant manager
# 3644    assistant manager
# Name: title, dtype: object
# ########################################################################################################################
# -----------------------------------------------assistant project manager------------------------------------------------
# 3630    assistant project manager
# 3631    assistant project manager
# 3632    assistant project manager
# Name: title, dtype: object
# ########################################################################################################################
# ----------------------------------------assurance - external audit(?!.*manager)-----------------------------------------
# 3598    assurance - external audit
# 3599    assurance - external audit
# 3600    assurance - external audit
# 3601    assurance - external audit
# 3602    assurance - external audit
# 3603    assurance - external audit
# Name: title, dtype: object
# ########################################################################################################################
# -------------------(?=.*(operations|operation))(?=.*(specialist|coordinator|associate))(?=.*(audit))--------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# ---------------------------------------------------area sales manager---------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# --------------------------------------------------area sales engineer---------------------------------------------------
# 3668    area sales engineer
# 3669    area sales engineer
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------------------------------area security manager--------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# ----------------------------------------------automation testing engineer-----------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# -------------------------------------------associate customer success manager-------------------------------------------
# 3615    associate customer success manager
# 3616    associate customer success manager
# Name: title, dtype: object
# ########################################################################################################################
# ------------------------------------------------assistant sales manager-------------------------------------------------
# 3628    assistant sales manager
# 3629    assistant sales manager
# Name: title, dtype: object
# ########################################################################################################################
# -----------------------------------------------------ar accountant------------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# -----------------------------------------------arabic english interpreter-----------------------------------------------
# 3693    arabic english interpreter
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------------------------backend developer----------------------------------------------------
# 3560    backend developer
# 3561    backend developer
# 3562    backend developer
# 3563    backend developer
# 3564    backend developer
# 3565    backend developer
# 3566    backend developer
# 3567    backend developer
# 3568    backend developer
# 3569    backend developer
# 3570    backend developer
# 3571    backend developer
# 3572    backend developer
# Name: title, dtype: object
# ########################################################################################################################
# ------------------------(?=.*(developer))(?=.*backend)^(?!.*(?:lead|manager|test automation)).*-------------------------
# 3560    backend developer
# 3561    backend developer
# 3562    backend developer
# 3563    backend developer
# 3564    backend developer
# 3565    backend developer
# 3566    backend developer
# 3567    backend developer
# 3568    backend developer
# 3569    backend developer
# 3570    backend developer
# 3571    backend developer
# 3572    backend developer
# Name: title, dtype: object
# ########################################################################################################################
# ----------------------------------------------------^web developer$-----------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# --------------------------------------(?=.*(web developer))^(?!.*(?:full stack)).*--------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# --------------------------------------------------------^barista--------------------------------------------------------
# 3554    barista
# 3555    barista
# Name: title, dtype: object
# ########################################################################################################################
# ----------------------------------------------(?=.*(bim))(?=.*(structur))-----------------------------------------------
# 3513    bim structure engineer
# 3514    bim structure engineer
# 3515    bim structure engineer
# 3516    bim structure engineer
# 3517    bim structure engineer
# 3518    bim structure engineer
# Name: title, dtype: object
# ########################################################################################################################
# --------------------------------------------(?<!associate )business analyst---------------------------------------------
# 3418    business analyst
# 3419    business analyst
# 3420    business analyst
# 3421    business analyst
# 3422    business analyst
# 3423    business analyst
# 3424    business analyst
# 3425    business analyst
# 3426    business analyst
# 3427    business analyst
# 3428    business analyst
# 3429    business analyst
# 3430    business analyst
# 3431    business analyst
# 3432    business analyst
# 3433    business analyst
# 3434    business analyst
# 3435    business analyst
# 3436    business analyst
# 3437    business analyst
# 3438    business analyst
# 3439    business analyst
# 3440    business analyst
# 3441    business analyst
# 3442    business analyst
# 3443    business analyst
# 3444    business analyst
# 3445    business analyst
# 3446    business analyst
# 3447    business analyst
# 3448    business analyst
# 3449    business analyst
# 3450    business analyst
# 3451    business analyst
# 3452    business analyst
# 3453    business analyst
# 3454    business analyst
# 3455    business analyst
# 3456    business analyst
# 3457    business analyst
# 3458    business analyst
# 3459    business analyst
# 3460    business analyst
# 3461    business analyst
# 3462    business analyst
# 3463    business analyst
# 3464    business analyst
# 3465    business analyst
# 3466    business analyst
# 3467    business analyst
# 3468    business analyst
# 3469    business analyst
# 3470    business analyst
# 3471    business analyst
# 3472    business analyst
# 3473    business analyst
# 3474    business analyst
# 3475    business analyst
# 3476    business analyst
# 3477    business analyst
# 3478    business analyst
# 3479    business analyst
# 3480    business analyst
# 3481    business analyst
# 3482    business analyst
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------------------^business development(\\s-|$)----------------------------------------------
# 3402    business development
# 3403    business development
# 3404    business development
# 3405    business development
# 3406    business development
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------------------business development executive---------------------------------------------
# 3393    business development executive
# 3394    business development executive
# 3395    business development executive
# 3396    business development executive
# 3397    business development executive
# 3398    business development executive
# 3399    business development executive
# Name: title, dtype: object
# ########################################################################################################################
# -----------------------------------------------business development lead------------------------------------------------
# 3392    business development lead
# Name: title, dtype: object
# ########################################################################################################################
# ---------(business development [a-z]+ manager)|(business development manager)|(manager .* business development)---------
# 3386    business development manager
# 3387    business development manager
# 3388    business development manager
# 3389    business development manager
# 3390    business development manager
# 3391    business development manager
# Name: title, dtype: object
# ########################################################################################################################
# ------------------------------------------business development representative-------------------------------------------
# 3377    business development representative
# 3378    business development representative
# 3379    business development representative
# 3380    business development representative
# 3381    business development representative
# 3382    business development representative
# 3383    business development representative
# 3384    business development representative
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------(business development specialist)|(specialist .* business development)-------------------------
# 3370    business development specialist
# 3371    business development specialist
# 3372    business development specialist
# 3373    business development specialist
# 3374    business development specialist
# 3375    business development specialist
# 3376    business development specialist
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------------------^business support(?!.*manager)---------------------------------------------
# 3352    business support
# Name: title, dtype: object
# ########################################################################################################################
# -----------------------------------------------------brand manager------------------------------------------------------
# 3495    brand manager
# 3496    brand manager
# 3497    brand manager
# 3498    brand manager
# 3499    brand manager
# 3500    brand manager
# 3501    brand manager
# 3502    brand manager
# 3503    brand manager
# 3504    brand manager
# Name: title, dtype: object
# ########################################################################################################################
# (?=.*(development))(?=.*(business))^(?!.*(?:manager|lead|office|director|executive|representative|specialist|associate)).*
# 3402    business development
# 3403    business development
# 3404    business development
# 3405    business development
# 3406    business development
# Name: title, dtype: object
# ########################################################################################################################
# ----------------------------------(?=.*(intelligence))(?=.*(engineer))(?=.*(business))----------------------------------
# 3363    business intelligence engineer
# 3364    business intelligence engineer
# 3365    business intelligence engineer
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------------(?=.*(research))(?=.*(business))^(?!.*(?:manager|lead)).*--------------------------------
# 3355    business research
# 3356    business research
# 3357    business research
# 3358    business research
# 3359    business research
# Name: title, dtype: object
# ########################################################################################################################
# ------------------------------------(?=.*(research))(?=.*(business))^(?=.*(manager))------------------------------------
# 3354    business research manager
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------------------(?=.*(research))(?=.*(business))^(?=.*(lead))--------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# ----------------------------------(?=.*(call))(?=.*(center))^(?!.*(?:manager|lead)).*-----------------------------------
# 3332    call center agent
# 3333    call center agent
# 3334    call center agent
# 3335    call center agent
# 3336    call center agent
# 3337    call center agent
# 3338    call center agent
# 3339    call center agent
# 3340    call center agent
# 3341    call center agent
# 3342    call center agent
# 3343    call center agent
# 3344    call center agent
# 3345    call center agent
# 3346    call center agent
# 3347    call center agent
# 3348    call center agent
# Name: title, dtype: object
# ########################################################################################################################
# ----------------------------------------(?=.*(call))(?=.*(center))^(?=.*(lead))-----------------------------------------
# 3330    call center lead
# 3331    call center lead
# Name: title, dtype: object
# ########################################################################################################################
# -----------------------------------(?=.*(call))(?=.*(center|centre))^(?=.*(manager))------------------------------------
# 3329    call center manager
# Name: title, dtype: object
# ########################################################################################################################
# --------------------------------------------------------cashier---------------------------------------------------------
# 3311    cashier
# 3312    cashier
# 3313    cashier
# 3314    cashier
# 3315    cashier
# 3316    cashier
# 3317    cashier
# Name: title, dtype: object
# ########################################################################################################################
# ----------------------------------------------------category manager----------------------------------------------------
# 3307    category manager
# 3308    category manager
# 3309    category manager
# 3310    category manager
# Name: title, dtype: object
# ########################################################################################################################
# ------------------------------------------------------(?=.*(ceo))-------------------------------------------------------
# 3300    ceo assistant
# Name: title, dtype: object
# ########################################################################################################################
# ----------------------------------------------^(?!.*demi).*chef de partie-----------------------------------------------
# 3287    chef de partie
# 3288    chef de partie
# 3289    chef de partie
# 3290    chef de partie
# 3291    chef de partie
# 3292    chef de partie
# 3293    chef de partie
# 3294    chef de partie
# Name: title, dtype: object
# ########################################################################################################################
# --------------------------------------------(?=.*(chief))(?=.*(accountant))---------------------------------------------
# 3276    chief accountant
# 3277    chief accountant
# 3278    chief accountant
# 3279    chief accountant
# 3280    chief accountant
# 3281    chief accountant
# 3282    chief accountant
# 3283    chief accountant
# Name: title, dtype: object
# ########################################################################################################################
# ----------------------------------------------------chief concierge-----------------------------------------------------
# 3274    chief concierge
# 3275    chief concierge
# Name: title, dtype: object
# ########################################################################################################################
# --------------------------------------------^(?!.*assistant).*chief engineer--------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# --------------------------------------------------------civil 3d--------------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# ---------------------------(?=.*engineer)(?=.*civil)^(?!.*(?:mechanical|manager|structure)).*---------------------------
# 3263    civil engineer
# 3264    civil engineer
# 3265    civil engineer
# 3266    civil engineer
# 3267    civil engineer
# 3268    civil engineer
# 3269    civil engineer
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------------------------------client partner manager-------------------------------------------------
# 3258    client partner manager
# Name: title, dtype: object
# ########################################################################################################################
# ----------------------------------------------------cluster director----------------------------------------------------
# 3236    cluster director
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------------------------commercial manager---------------------------------------------------
# 3210    commercial manager
# 3211    commercial manager
# Name: title, dtype: object
# ########################################################################################################################
# -----------------------------------------------------commi( |s |s$)-----------------------------------------------------
# 3198    commis
# 3199    commis
# 3200    commis
# 3201    commis
# 3202    commis
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------------------------compliance manager---------------------------------------------------
# 3193    compliance manager
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------^(?!.*(?:chief|trade|payroll|tax)).*compliance officer---------------------------------
# 3190    compliance officer
# 3191    compliance officer
# 3192    compliance officer
# Name: title, dtype: object
# ########################################################################################################################
# -----------------------------------------^(?!.*(?:manager|senior)).*^consulting-----------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# ----------------------------------------------^consulting.*senior manager-----------------------------------------------
# 3168    consulting senior manager
# Name: title, dtype: object
# ########################################################################################################################
# ------------------------------------------------content (creator|maker)-------------------------------------------------
# 3158    content creator
# 3159    content creator
# 3160    content creator
# 3161    content creator
# 3162    content creator
# 3163    content creator
# Name: title, dtype: object
# ########################################################################################################################
# ----------------------------------------------content (writer|researcher)-----------------------------------------------
# 3146    content writer
# 3147    content writer
# Name: title, dtype: object
# ########################################################################################################################
# ------------------------------------------------^contract(s)? specialist------------------------------------------------
# 3143    contract specialist
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------------------------------contract(s)? engineer--------------------------------------------------
# 3140    contracts engineer
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------------------------controls engineer----------------------------------------------------
# 3133    controls engineer
# 3134    controls engineer
# 3135    controls engineer
# Name: title, dtype: object
# ########################################################################################################################
# ------------------------------------------------------^coordinator------------------------------------------------------
# 3125    coordinator
# 3126    coordinator
# 3127    coordinator
# 3128    coordinator
# 3129    coordinator
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------------------------------------copywriter-------------------------------------------------------
# 3123    copywriter
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------------------------------^cost control engineer-------------------------------------------------
# 3111    cost control engineer
# 3112    cost control engineer
# Name: title, dtype: object
# ########################################################################################################################
# --------------------------------------------------------^counsel--------------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# ----------------(?=.*(operations|operation))(?=.*(manager|senior manager|area manager))(?=.*(customer))-----------------
# 3052    customer operations manager
# 3053    customer operations manager
# Name: title, dtype: object
# ########################################################################################################################
# -----------------------------------------------customer service executive-----------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# ------------(?=.*(operations|operation))(?=.*(specialist|coordinator|associate))(?=.*(lost\\s+and\\s+found))------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# -----------------------------------------------------cyber security-----------------------------------------------------
# 2963    cyber security
# 2964    cyber security
# 2965    cyber security
# 2966    cyber security
# 2967    cyber security
# 2968    cyber security
# 2969    cyber security
# Name: title, dtype: object
# ########################################################################################################################
# --------------------------------------------------------captian---------------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# -------------------------------------------------center quality manager-------------------------------------------------
# 3301    center quality manager
# 3302    center quality manager
# 3303    center quality manager
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------------------------channel management---------------------------------------------------
# 3297    channel management
# 3298    channel management
# Name: title, dtype: object
# ########################################################################################################################
# -----------------------------------------------------^consultant.*------------------------------------------------------
# 3169    consultant
# 3170    consultant
# 3171    consultant
# 3172    consultant
# 3173    consultant
# 3174    consultant
# 3175    consultant
# 3176    consultant
# 3177    consultant
# 3178    consultant
# 3179    consultant
# 3180    consultant
# 3181    consultant
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------------------^(consulting)(?!.*(?:manager|quality|lead)).*--------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# -----------------------------^(?=.*(content))(?=.*(specialist))^(?!.*(?:marketing|photo)).*-----------------------------
# 3148    content specialist
# 3149    content specialist
# 3150    content specialist
# 3151    content specialist
# 3152    content specialist
# 3153    content specialist
# 3154    content specialist
# 3155    content specialist
# Name: title, dtype: object
# ########################################################################################################################
# -----------------------------------------(?=.*(customer))(?=.*(representative))-----------------------------------------
# 3037    customer representative
# 3038    customer representative
# 3039    customer representative
# 3040    customer representative
# 3041    customer representative
# 3042    customer representative
# 3043    customer representative
# 3044    customer representative
# 3045    customer representative
# 3046    customer representative
# 3047    customer representative
# 3048    customer representative
# 3049    customer representative
# 3050    customer representative
# Name: title, dtype: object
# ########################################################################################################################
# --------------------------------------------(?=.*(customer))(?=.*(service))---------------------------------------------
# 3003    customer service
# 3004    customer service
# 3005    customer service
# 3006    customer service
# 3007    customer service
# 3008    customer service
# 3009    customer service
# 3010    customer service
# 3011    customer service
# 3012    customer service
# 3013    customer service
# 3014    customer service
# 3015    customer service
# 3016    customer service
# 3017    customer service
# 3018    customer service
# 3019    customer service
# 3020    customer service
# 3021    customer service
# 3022    customer service
# 3023    customer service
# 3024    customer service
# 3025    customer service
# 3026    customer service
# 3027    customer service
# 3028    customer service
# 3029    customer service
# 3030    customer service
# 3031    customer service
# 3032    customer service
# 3033    customer service
# 3034    customer service
# 3035    customer service
# 3036    customer service
# Name: title, dtype: object
# ########################################################################################################################
# -----------------------------------(?=.*(customer))(?=.*(support))(?=.*(specialist))------------------------------------
# 2973    customer support specialist
# 2974    customer support specialist
# 2975    customer support specialist
# 2976    customer support specialist
# 2977    customer support specialist
# 2978    customer support specialist
# 2979    customer support specialist
# 2980    customer support specialist
# 2981    customer support specialist
# 2982    customer support specialist
# 2983    customer support specialist
# 2984    customer support specialist
# 2985    customer support specialist
# 2986    customer support specialist
# 2987    customer support specialist
# Name: title, dtype: object
# ########################################################################################################################
# ----------------------------------(?=.*(customer))(?=.*(experience))(?=.*(specialist))----------------------------------
# 3058    customer experience specialist
# 3059    customer experience specialist
# 3060    customer experience specialist
# 3061    customer experience specialist
# 3062    customer experience specialist
# 3063    customer experience specialist
# 3064    customer experience specialist
# 3065    customer experience specialist
# 3066    customer experience specialist
# 3067    customer experience specialist
# 3068    customer experience specialist
# Name: title, dtype: object
# ########################################################################################################################
# ------------------------------------------------------^data center------------------------------------------------------
# 2932    data center engineer
# 2933    data center engineer
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------------(?=.*(data))(?=.*(analy))^(?!.*(?:manager|quality|lead)).*-------------------------------
# 2938    data analyst
# 2939    data analyst
# 2940    data analyst
# 2941    data analyst
# 2942    data analyst
# 2943    data analyst
# 2944    data analyst
# 2945    data analyst
# 2946    data analyst
# 2947    data analyst
# 2948    data analyst
# 2949    data analyst
# 2950    data analyst
# 2951    data analyst
# 2952    data analyst
# 2953    data analyst
# 2954    data analyst
# 2955    data analyst
# 2956    data analyst
# 2957    data analyst
# 2958    data analyst
# 2959    data analyst
# Name: title, dtype: object
# ########################################################################################################################
# ----------------------------------------------------database expert-----------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# -----------------------------------------------------^data engineer-----------------------------------------------------
# 2907    data engineer
# 2908    data engineer
# 2909    data engineer
# 2910    data engineer
# 2911    data engineer
# ...
# --------------------(?=.*software)(?=.*(engineer|engineering))(?=.*(frontend|front end|front\-end))---------------------
# 510    software frontend engineer
# 511    software frontend engineer
# 512    software frontend engineer
# 513    software frontend engineer
# 514    software frontend engineer
# 515    software frontend engineer
# 516    software frontend engineer
# 517    software frontend engineer
# 518    software frontend engineer
# 519    software frontend engineer
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------------(?=.*(engineer|engineering))(?=.*frontend)---------------------------------------
# 510    software frontend engineer
# 511    software frontend engineer
# 512    software frontend engineer
# 513    software frontend engineer
# 514    software frontend engineer
# 515    software frontend engineer
# 516    software frontend engineer
# 517    software frontend engineer
# 518    software frontend engineer
# 519    software frontend engineer
# Name: title, dtype: object
# ########################################################################################################################
# -----(?=.*(engineer|engineering))(?=.*(fullstack|full stack|full\-stack))^(?!.*(?:lead|manager|test automation)).*------
# 520    software engineer fullstack
# 521    software engineer fullstack
# 522    software engineer fullstack
# 523    software engineer fullstack
# 524    software engineer fullstack
# Name: title, dtype: object
# ########################################################################################################################
# (?=.*software)(?=.*(engineer|engineering))(?=.*(fullstack|full stack|full\-stack))^(?!.*(?:lead|manager|test automation)).*
# 520    software engineer fullstack
# 521    software engineer fullstack
# 522    software engineer fullstack
# 523    software engineer fullstack
# 524    software engineer fullstack
# Name: title, dtype: object
# ########################################################################################################################
# ----------------------(?=.*software)(?=.*(engineer|engineering))(?=.*(mobile|ios|android|flutter))----------------------
# 487    software mobile engineer
# 488    software mobile engineer
# 489    software mobile engineer
# 490    software mobile engineer
# 491    software mobile engineer
# 492    software mobile engineer
# 493    software mobile engineer
# 494    software mobile engineer
# 495    software mobile engineer
# 496    software mobile engineer
# 497    software mobile engineer
# 498    software mobile engineer
# 499    software mobile engineer
# 500    software mobile engineer
# 501    software mobile engineer
# 502    software mobile engineer
# 503    software mobile engineer
# 504    software mobile engineer
# Name: title, dtype: object
# ########################################################################################################################
# -----------------------------(?=.*(engineer|engineering))(?=.*(mobile|ios|android|flutter))-----------------------------
# 487    software mobile engineer
# 488    software mobile engineer
# 489    software mobile engineer
# 490    software mobile engineer
# 491    software mobile engineer
# 492    software mobile engineer
# 493    software mobile engineer
# 494    software mobile engineer
# 495    software mobile engineer
# 496    software mobile engineer
# 497    software mobile engineer
# 498    software mobile engineer
# 499    software mobile engineer
# 500    software mobile engineer
# 501    software mobile engineer
# 502    software mobile engineer
# 503    software mobile engineer
# 504    software mobile engineer
# Name: title, dtype: object
# ########################################################################################################################
# ----------------------------------------------------store manager.*-----------------------------------------------------
# 414    store manager
# 415    store manager
# 416    store manager
# 417    store manager
# Name: title, dtype: object
# ########################################################################################################################
# ------------(?=.*(operations|operation))(?=.*(manager|senior manager|area manager))(?=.*(strategy|planning))------------
# 401    strategy & operations manager
# 402    strategy & operations manager
# Name: title, dtype: object
# ########################################################################################################################
# --------------------------------^(?!.*manager).*supply (chain|planning|demand|analyst).*--------------------------------
# 354    supply chain analyst
# 355    supply chain analyst
# 356    supply chain analyst
# 357    supply chain analyst
# 358    supply chain analyst
# 359    supply chain analyst
# 360    supply chain analyst
# 361    supply chain analyst
# 362    supply chain analyst
# 363    supply chain analyst
# 364    supply chain analyst
# 365    supply chain analyst
# 366    supply chain analyst
# 367    supply chain analyst
# 368    supply chain analyst
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------------------------------supply chain executive-------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# -----------------(?i)(?=.*\\b(?:(manager|management))\\b).*\\bsupply (chain|planning|demand|analyst).*------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# ---------------------------------------------------technical support----------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# ----------------------------------------------------support engineer----------------------------------------------------
# 310    support engineer
# 311    support engineer
# 312    support engineer
# 313    support engineer
# 314    support engineer
# 315    support engineer
# 316    support engineer
# 317    support engineer
# 318    support engineer
# 319    support engineer
# 320    support engineer
# 321    support engineer
# 322    support engineer
# 323    support engineer
# 324    support engineer
# 325    support engineer
# 326    support engineer
# 327    support engineer
# 328    support engineer
# 329    support engineer
# 330    support engineer
# 331    support engineer
# 332    support engineer
# 333    support engineer
# 334    support engineer
# 335    support engineer
# 336    support engineer
# 337    support engineer
# 338    support engineer
# 339    support engineer
# 340    support engineer
# 341    support engineer
# 342    support engineer
# 343    support engineer
# 344    support engineer
# 345    support engineer
# 346    support engineer
# 347    support engineer
# 348    support engineer
# 349    support engineer
# 350    support engineer
# Name: title, dtype: object
# ########################################################################################################################
# --------------------------------------------------technical support &---------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# -------------------------------------------------system administrator.*-------------------------------------------------
# 296    system administrator
# 297    system administrator
# 298    system administrator
# 299    system administrator
# 300    system administrator
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------------------------------system(s)? engineer.*--------------------------------------------------
# 287    system engineer
# 288    system engineer
# 289    system engineer
# 290    system engineer
# 291    system engineer
# 292    system engineer
# 293    system engineer
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------------(?=.*(Account))(?=.*(Manager))(?=.*(Sale))---------------------------------------
# 941    sales account manager
# 942    sales account manager
# 943    sales account manager
# 944    sales account manager
# 945    sales account manager
# 946    sales account manager
# 947    sales account manager
# 948    sales account manager
# 949    sales account manager
# 950    sales account manager
# 951    sales account manager
# 952    sales account manager
# 953    sales account manager
# 954    sales account manager
# 955    sales account manager
# 956    sales account manager
# 957    sales account manager
# 958    sales account manager
# 959    sales account manager
# Name: title, dtype: object
# ########################################################################################################################
# -----------------------------------------^talent acquisition .*(manager|head).*-----------------------------------------
# 284    talent acquisition manager
# 285    talent acquisition manager
# 286    talent acquisition manager
# Name: title, dtype: object
# ########################################################################################################################
# --------------------------------------talent acquisition (specialist|partner|&).*---------------------------------------
# 261    talent acquisition specialist
# 262    talent acquisition specialist
# 263    talent acquisition specialist
# 264    talent acquisition specialist
# 265    talent acquisition specialist
# 266    talent acquisition specialist
# 267    talent acquisition specialist
# 268    talent acquisition specialist
# 269    talent acquisition specialist
# 270    talent acquisition specialist
# 271    talent acquisition specialist
# 272    talent acquisition specialist
# 273    talent acquisition specialist
# 274    talent acquisition specialist
# 275    talent acquisition specialist
# 276    talent acquisition specialist
# 277    talent acquisition specialist
# 278    talent acquisition specialist
# 279    talent acquisition specialist
# 280    talent acquisition specialist
# 281    talent acquisition specialist
# 282    talent acquisition specialist
# Name: title, dtype: object
# ########################################################################################################################
# ------------------------------^talent acquisition and learning and development specialist-------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# ------------------------------------------------^technical consulting.*-------------------------------------------------
# 231    technical consulting
# 232    technical consulting
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------------(?!.*\\b(java|(ai/ml)|.net)\\b).*^(technical|tech) lead.*--------------------------------
# 205    technical lead
# 206    technical lead
# 207    technical lead
# 208    technical lead
# 209    technical lead
# 210    technical lead
# 211    technical lead
# 212    technical lead
# 213    technical lead
# 214    technical lead
# 215    technical lead
# 216    technical lead
# 217    technical lead
# 218    technical lead
# 219    technical lead
# 220    technical lead
# 221    technical lead
# 222    technical lead
# 223    technical lead
# Name: title, dtype: object
# ########################################################################################################################
# -------------------------------------------------(technical|tech) lead--------------------------------------------------
# 205    technical lead
# 206    technical lead
# 207    technical lead
# 208    technical lead
# 209    technical lead
# 210    technical lead
# 211    technical lead
# 212    technical lead
# 213    technical lead
# 214    technical lead
# 215    technical lead
# 216    technical lead
# 217    technical lead
# 218    technical lead
# 219    technical lead
# 220    technical lead
# 221    technical lead
# 222    technical lead
# 223    technical lead
# Name: title, dtype: object
# ########################################################################################################################
# ------------------------------------------------testing engineer|tester-------------------------------------------------
# 136    testing engineer
# 137    testing engineer
# 138    testing engineer
# 139    testing engineer
# 140    testing engineer
# 141    testing engineer
# 142    testing engineer
# 143    testing engineer
# 144    testing engineer
# 145    testing engineer
# 146    testing engineer
# 147    testing engineer
# 148    testing engineer
# 149    testing engineer
# 150    testing engineer
# 151    testing engineer
# 152    testing engineer
# Name: title, dtype: object
# ########################################################################################################################
# ----------------------------------------------------software tester-----------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# ----------------------------------------------------training manager----------------------------------------------------
# 119    training manager
# 120    training manager
# 121    training manager
# Name: title, dtype: object
# ########################################################################################################################
# ----------------------------------------------^treasury senior accountant-----------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# -----------------------------------------------^treasury (section|head).*-----------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# ------------------------------------------------------^treasurer$-------------------------------------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# -----------------------------^treasur(y|er)\\s?(specialist|senior specialist|and| - emea).*-----------------------------
# Series([], Name: title, dtype: object)
# ########################################################################################################################
# ---------------------------------------(?=.*(designer))(?=.*(ux/ui|ui/ux|ux|ui))----------------------------------------
# 70    ux/ui designer
# 71    ux/ui designer
# 72    ux/ui designer
# 73    ux/ui designer
# 74    ux/ui designer
# 75    ux/ui designer
# 76    ux/ui designer
# 77    ux/ui designer
# 78    ux/ui designer
# Name: title, dtype: object
# ########################################################################################################################
# ---------------------------------------(?=.*(developer))(?=.*(ux/ui|ui/ux|ux|ui))---------------------------------------
# 66    ux/ui developer
# 67    ux/ui developer
# 68    ux/ui developer
# 69    ux/ui developer
# Name: title, dtype: object
# ########################################################################################################################

# %%
edit_title(df_egypt, final_mapping_title_egypt)
df_egypt.title.value_counts()
# Out:
# title
# Accountant                                                                                                                 83
# Business Analyst                                                                                                           65
# Account Manager                                                                                                            63
# Software Engineer                                                                                                          52
# Support Engineer                                                                                                           41
# Graphic Design                                                                                                             38
# Customer Service                                                                                                           34
# Sales Manager                                                                                                              32
# Marketing Manager                                                                                                          28
# Product Manager                                                                                                            28
# Finance Manager                                                                                                            26
# Data Engineer                                                                                                              23
# Sales Executive                                                                                                            23
# Data Analyst                                                                                                               22
# Talent Acquisition Specialist                                                                                              22
# Financial Analyst                                                                                                          21
# Fullstack Developer                                                                                                        21
# Mechanical Engineer                                                                                                        20
# Sales Account Manager                                                                                                      19
# Technical Lead                                                                                                             19
# Devops Engineer                                                                                                            19
# Electrical Design Engineer                                                                                                 19
# Security Engineer                                                                                                          19
# Account Assistant                                                                                                          18
# Software Mobile Engineer                                                                                                   18
# Call Center Agent                                                                                                          17
# Testing Engineer                                                                                                           17
# Frontend Developer                                                                                                         17
# Hr Specialist                                                                                                              16
# Project Manager                                                                                                            15
# Customer Support Specialist                                                                                                15
# Supply Chain Analyst                                                                                                       15
# Mobile Developer                                                                                                           15
# Engineer Manager                                                                                                           15
# Account Receivable                                                                                                         14
# Office Engineer                                                                                                            14
# Ai/Ml Engineer                                                                                                             14
# Office Manager                                                                                                             14
# Customer Representative                                                                                                    14
# Medical Representative                                                                                                     13
# Backend Developer                                                                                                          13
# Purchasing Specialist                                                                                                      13
# Executive Assistant                                                                                                        13
# General Accountant                                                                                                         13
# Internal Auditor                                                                                                           13
# Consultant                                                                                                                 13
# Architectural Engineer                                                                                                     12
# Analyst                                                                                                                    12
# Data Scientist                                                                                                             12
# Finance Controller                                                                                                         11
# Accounting Supervisor                                                                                                      11
# Customer Experience Specialist                                                                                             11
# Quality Engineer                                                                                                           11
# Software Frontend Engineer                                                                                                 10
# Treasury Accountant                                                                                                        10
# Sales Representative                                                                                                       10
# Java Developer                                                                                                             10
# Brand Manager                                                                                                              10
# Engineer Planning                                                                                                          10
# Account Executive                                                                                                           9
# Sales Development Representative                                                                                            9
# Accounts Payable                                                                                                            9
# Ux/Ui Designer                                                                                                              9
# Product Designer                                                                                                            9
# Qa Engineer                                                                                                                 9
# Financial Accountant                                                                                                        8
# Operations Manager                                                                                                          8
# Content Specialist                                                                                                          8
# Chief Accountant                                                                                                            8
# Assistant Manager                                                                                                           8
# Demi Coding Instructor Physical                                                                                             8
# Front Desk Agent                                                                                                            8
# Estimator                                                                                                                   8
# Business Development Representative                                                                                         8
# Hr Officer                                                                                                                  8
# Chef De Partie                                                                                                              8
# Digital Marketing Specialist                                                                                                8
# Hr Manager                                                                                                                  7
# Scrum Master                                                                                                                7
# Product Owner                                                                                                               7
# It Support                                                                                                                  7
# Marketing Specialist                                                                                                        7
# Business Development Specialist                                                                                             7
# Design Engineer                                                                                                             7
# Civil Engineer                                                                                                              7
# Business Development Executive                                                                                              7
# Customer Success Manager                                                                                                    7
# Cashier                                                                                                                     7
# Cyber Security                                                                                                              7
# System Engineer                                                                                                             7
# Sales Engineer                                                                                                              7
# Sales Director                                                                                                              6
# Hr Generalist                                                                                                               6
# Content Creator                                                                                                             6
# Ap Accountant                                                                                                               6
# Engineer                                                                                                                    6
# Solution Architect                                                                                                          6
# Finance Director                                                                                                            6
# Logistics Coordinator                                                                                                       6
# Business Development Manager                                                                                                6
# Hub Operations Coordinator                                                                                                  6
# Software Developer                                                                                                          6
# Assurance - External Audit                                                                                                  6
# Bim Structure Engineer                                                                                                      6
# Maintenance Technician                                                                                                      5
# Business Research                                                                                                           5
# Safety Specialist                                                                                                           5
# Operations Specialist                                                                                                       5
# Operations Engineer                                                                                                         5
# Quality Assurance Engineer                                                                                                  5
# Assistant Director                                                                                                          5
# Coordinator                                                                                                                 5
# Commis                                                                                                                      5
# Design Manager                                                                                                              5
# Finance Analyst                                                                                                             5
# Treasury Specialist                                                                                                         5
# Business Development                                                                                                        5
# Fp&A Analyst                                                                                                                5
# System Administrator                                                                                                        5
# Account Payable Accountant                                                                                                  5
# Interior Designer                                                                                                           5
# Social Media Moderator                                                                                                      5
# It Specialist                                                                                                               5
# Legal Counsel                                                                                                               5
# Sales Operations Specialist                                                                                                 4
# Category Manager                                                                                                            4
# Vendor Management Specialist - 1 Year Contract                                                                              4
# Social Media Specialist                                                                                                     4
# Kitchen Steward                                                                                                             4
# Integration Developer                                                                                                       4
# Java Engineer                                                                                                               4
# Service Delivery Associate – Payroll                                                                                        4
# Service Delivery Associate - Payroll                                                                                        4
# Cse Engineer, Systems                                                                                                       4
# Marketing Executive                                                                                                         4
# Production Manager                                                                                                          4
# Procurement Specialist                                                                                                      4
# Ux/Ui Developer                                                                                                             4
# Personal Banker                                                                                                             4
# Personal Assistant                                                                                                          4
# Nutrition Marketing Projects Specialist- 1 Year Contract                                                                    4
# Media Buyer                                                                                                                 4
# Customer Success Specialist                                                                                                 4
# Structural Engineer                                                                                                         4
# Financial Planning Analyst                                                                                                  4
# Treasury Lead                                                                                                               4
# Facilities Coordinator                                                                                                      4
# Store Manager                                                                                                               4
# Executive Chef                                                                                                              4
# Document Controller                                                                                                         4
# Electrical Maintenance Engineer                                                                                             4
# Data Intelligence Engineer                                                                                                  4
# Data Operations Specialist                                                                                                  4
# Receptionist                                                                                                                4
# Reservations Agent                                                                                                          4
# Ai Engineer                                                                                                                 4
# Warehouse Manager                                                                                                           4
# Waiter                                                                                                                      4
# Video Editor                                                                                                                4
# Assistant Project Manager                                                                                                   3
# Sales Assistant                                                                                                             3
# Warehouse Specialist                                                                                                        3
# Project Coordinator                                                                                                         3
# Project Engineer                                                                                                            3
# Projects Planner                                                                                                            3
# Data Quality Analyst                                                                                                        3
# Sales Coordinator                                                                                                           3
# Sales Employee                                                                                                              3
# Recruitment Specialist                                                                                                      3
# Project Administrator                                                                                                       3
# Product Analyst                                                                                                             3
# Product Marketing Engineer                                                                                                  3
# People Partner                                                                                                              3
# Performance Marketing Specialist                                                                                            3
# Pharmacist                                                                                                                  3
# Process Engineer                                                                                                            3
# Odoo Developer                                                                                                              3
# Office Admin                                                                                                                3
# Executive (Cost Control)                                                                                                    3
# Executive (Logistics)                                                                                                       3
# Supervisor (Strategy And Investment)                                                                                        3
# Membership Administrator                                                                                                    3
# Compliance Officer                                                                                                          3
# Center Quality Manager                                                                                                      3
# Cost Accountant                                                                                                             3
# Service Development Senior Specialist                                                                                       3
# Marketing Analyst                                                                                                           3
# Service Manager                                                                                                             3
# Service Performance And Reporting Specialist                                                                                3
# Service Renewal Manager, Mobile Surgery                                                                                     3
# Lead Auditor                                                                                                                3
# Logistics Specialist                                                                                                        3
# Maintenance Manager                                                                                                         3
# It Delivery Assurance Officer                                                                                               3
# It Manager                                                                                                                  3
# Site Engineer                                                                                                               3
# Hr Intern                                                                                                                   3
# Hr Lead                                                                                                                     3
# Hse Advisor                                                                                                                 3
# Treasury And Dcm Analyst                                                                                                    3
# Business Developer                                                                                                          3
# Executive Secretary                                                                                                         3
# Talent Acquisition Manager                                                                                                  3
# Talent Pool - Sales Associate Alexandria, Egypt (3 Months)                                                                  3
# Tax Associate, Mea                                                                                                          3
# Controls Engineer                                                                                                           3
# Technical Writer                                                                                                            3
# Assurance Graduate Programme - Egypt                                                                                        3
# Head Of Service Management                                                                                                  3
# Housekeeping Order Taker                                                                                                    3
# Housekeeping Supervisor                                                                                                     3
# Training Manager                                                                                                            3
# Software Project Manager- Egypt                                                                                             3
# Telesales Representative                                                                                                    3
# Cloud Infrastructure Engineer                                                                                               3
# Business Intelligence Engineer                                                                                              3
# Gl Accountant                                                                                                               3
# Global Procurement Associate Analyst                                                                                        3
# Sales Analyst                                                                                                               3
# Art Director                                                                                                                3
# Quote Administrator                                                                                                         3
# React Native Developer                                                                                                      3
# Recreation Attendant                                                                                                        3
# Assurance Summer Interns - Egypt                                                                                            3
# Ar Executive                                                                                                                3
# Collections Specialist                                                                                                      3
# Test Engineer                                                                                                               3
# Assistant Engineer                                                                                                          2
# Commercial Head - Human Pharma                                                                                              2
# Revenue Manager                                                                                                             2
# Reservations Manager                                                                                                        2
# Application Specialist                                                                                                      2
# 3D Designer                                                                                                                 2
# Washer Man                                                                                                                  2
# Visual Merchandise Group Leader | Ikea | Cairo Festival City                                                                2
# A/C Technician                                                                                                              2
# Customer Experience Coordinator (12 Months Contract)                                                                        2
# Customer Accounts Specialist                                                                                                2
# Architect (Egypt,Cairo)                                                                                                     2
# Sales Excellence Manager                                                                                                    2
# Automation Manager                                                                                                          2
# Recreation Supervisor                                                                                                       2
# Recreation Receptionist                                                                                                     2
# Record-To-Report (R2R) Accountant                                                                                           2
# Capabilities Business Partner & Compliance Champion                                                                         2
# Quality Supervisor                                                                                                          2
# Quantity Surveyor Senior Engineer                                                                                           2
# Assistant Business Navigator | Retail | Ikea - Moa Egypt                                                                    2
# Area Sales Engineer                                                                                                         2
# Sales Administrator                                                                                                         2
# Specialist Fraud Prevention - Regional Asset Protection - Egypt                                                             2
# Specialist (Total Rewards & Benefits)                                                                                       2
# Specialist (Taxation)                                                                                                       2
# First Mile Hub Supervisor                                                                                                   2
# Financial Planning & Analyst Manager                                                                                        2
# Guest Relations Supervisor (Female)                                                                                         2
# Guest Relations Officer - Holiday Inn Cairo Citystars                                                                       2
# Spa Therapist                                                                                                               2
# Spa Receptionist                                                                                                            2
# Spa Manager - Semiramis Intercontinental Cairo                                                                              2
# Spa Beautician                                                                                                              2
# General Ledger Accountant (Gl) | Real Estate Development                                                                    2
# Future Careers Recruitment Operations Specialist                                                                            2
# Cloud Senior Engineer                                                                                                       2
# Cloud Devops Engineer                                                                                                       2
# Cloud Automation Engineer                                                                                                   2
# Teller - Madinaty Area                                                                                                      2
# Telesales Specialist                                                                                                        2
# Chief Steward - Crowne Plaza West Cairo -Arkan                                                                              2
# Chief Concierge                                                                                                             2
# Fullstack Developer Lead                                                                                                    2
# Hr Employer Branding Marketer - Ihg Cairo Citystars Hotels                                                                  2
# Software Quality Control Engineer                                                                                           2
# Software Project Manager                                                                                                    2
# Hr Business Partner, Egypt                                                                                                  2
# Hr Business Partner Factory Distribution Transformers                                                                       2
# Sw Developer                                                                                                                2
# Trade Sales Representative (Outsourced Opportunity)                                                                         2
# Total Rewards Specialist                                                                                                    2
# Bookkeeping Administrator                                                                                                   2
# Biologic Business Partner – Cairo                                                                                           2
# Bim Architect Engineer                                                                                                      2
# Bid Specialist                                                                                                              2
# Benha University - Job Fair                                                                                                 2
# Bellboy                                                                                                                     2
# Captain                                                                                                                     2
# Strategic Sourcing Specialist                                                                                               2
# Strategic Hospitality Vertical Sales Specialist                                                                             2
# Front Desk Clerk - Intercontinental Cairo Citystars                                                                         2
# Food And Beverage Manager                                                                                                   2
# Specialist Risk, Compliance, Icv & Esg                                                                                      2
# Housekeeping Attendant                                                                                                      2
# Head Of Helpdesk Support Services                                                                                           2
# Head Of Communications, Egypt                                                                                               2
# Hardware Engineer                                                                                                           2
# Ie Supervisor                                                                                                               2
# Software Development Engineer                                                                                               2
# Software Developer (Vois)                                                                                                   2
# Ux Researcher                                                                                                               2
# Associate Customer Success Manager                                                                                          2
# Associate Community Executive                                                                                               2
# Associate                                                                                                                   2
# Assistant Vice President - Treasury Technology (Finmechanics Converge)                                                      2
# Technical Recruiter                                                                                                         2
# Technical Project Manager                                                                                                   2
# Commercial Policy & Pricing Transformation Manager                                                                          2
# Commercial Marketing Executive                                                                                              2
# Control & Reporting Asst Analyst                                                                                            2
# Content Writer                                                                                                              2
# Data Collector                                                                                                              2
# Data Center Engineer                                                                                                        2
# Data Analytics Team Lead- Sustainability Focus                                                                              2
# Assistant Sales Manager                                                                                                     2
# Business Developer (Hybrid)                                                                                                 2
# Execution Pmo                                                                                                               2
# Etic, Financial Planning & Analyst (Fp&A) Senior Manager                                                                    2
# Estimating Supervisor                                                                                                       2
# Finance Account                                                                                                             2
# Facility Engineer                                                                                                           2
# Facilities Manager - Property - Business Services                                                                           2
# Stewarding Shift Leader                                                                                                     2
# Exports Director                                                                                                            2
# Export Manager                                                                                                              2
# Experienced Customer Relationship Professional                                                                              2
# Strategy Associate                                                                                                          2
# Strategy & Operations Manager                                                                                               2
# Customer Operations Manager                                                                                                 2
# Customer Marketing Specialist                                                                                               2
# Demi Chef De Partie                                                                                                         2
# Social Media Manager                                                                                                        2
# Hr Service Delivery Associate – Compensations & Benefits                                                                    2
# Site Manager                                                                                                                2
# It Engineer                                                                                                                 2
# It Delivery Assurance                                                                                                       2
# International Automotive Task Force (Iatf - Lead Auditor)                                                                   2
# Information Security                                                                                                        2
# Manager                                                                                                                     2
# Maintenance Engineer                                                                                                        2
# Lost And Found Operations Specialist                                                                                        2
# Ships Agency Manager, Egypt                                                                                                 2
# Logistics Officer                                                                                                           2
# Localization Project Manager (Hybrid)                                                                                       2
# Lifeguard                                                                                                                   2
# Lebanese Chef                                                                                                               2
# Learning & Development Specialist                                                                                           2
# Kitchen Technician                                                                                                          2
# Services Sales Representative                                                                                               2
# Marketing Lead                                                                                                              2
# Marketing Director                                                                                                          2
# Marketing Admin                                                                                                             2
# Marketing & Pr Specialist                                                                                                   2
# Manufacturing Warehouse Assistant Supervisor                                                                                2
# Manufacturing Engineer                                                                                                      2
# Manager Facilities & Services (Workplace Management)                                                                        2
# Manager - Customer & Market Knowledge - Customer & Technology - Egypt                                                       2
# Medical Devices Auditor                                                                                                     2
# Media Buyer Lead                                                                                                            2
# Service Implementation/Lifecyle Manager Sie/Slm(Cloud)                                                                      2
# Service Delivery Manager                                                                                                    2
# Service Delivery Associate – Hire To Retire Helpdesk                                                                        2
# Service Delivery Associate – Finance Helpdesk                                                                               2
# Crm Representative                                                                                                          2
# Creative Director                                                                                                           2
# Technical Consulting                                                                                                        2
# Cost Controller                                                                                                             2
# Cost Control Engineer                                                                                                       2
# Cost Control Accountant                                                                                                     2
# Channel Management                                                                                                          2
# Consumer Experience Strategy Manager                                                                                        2
# Technician                                                                                                                  2
# Media Assistant                                                                                                             2
# Mechanical Section Head - Buildings                                                                                         2
# Mechanical Maintenance Engineer                                                                                             2
# Mechanical Design Engineer                                                                                                  2
# Services Site Senior Engineer                                                                                               2
# Security Supervisor                                                                                                         2
# Security Senior Officer                                                                                                     2
# Security Project Manager                                                                                                    2
# Security Officer                                                                                                            2
# Security Architect (Consultant)                                                                                             2
# ...
# Triple Play Outdoor Representative                                                                                          1
# Triple Play Representative                                                                                                  1
# Turbomachinery Automation Project Intern (Fresh Graduate Or Last Year Only)                                                 1
# Two Weeks Multiple Destination Internship Program - Egypt                                                                   1
# Ui Development Lead                                                                                                         1
# Ui/Ux Design Lead (Fintech Industry)                                                                                        1
# University Of Canada Ef - April 2025                                                                                        1
# Upstream Quality Specialist                                                                                                 1
# Utilities Engineer                                                                                                          1
# Ux                                                                                                                          1
# Audio Technician - Blue Man Group - Luxor                                                                                   1
# Audio Transcription Specialist                                                                                              1
# Audit Manager (Banking) | External Audit | Audit & Assurance | Egypt                                                        1
# Auditor                                                                                                                     1
# Associate - Senior Group Landscape Architect (Egypt,Cairo)                                                                  1
# Associate - Stock Control - Faces Egypt Retail Store Operations · Cairo                                                     1
# Associate - Visual Merchandising - Egypt Visual Merchandising · Cairo                                                       1
# Associate Channel / Partner Promotion Vision Care (Alexandria East)                                                         1
# Associate Data Engineer                                                                                                     1
# Associate Infrastructure Engineer                                                                                           1
# Associate Principal Engineer                                                                                                1
# Associate Project Director                                                                                                  1
# Associate Seasoning Flavorist (Savory Snacks)                                                                               1
# Associate Software Engineer                                                                                                 1
# Associate Staff Engineer                                                                                                    1
# Associate Vendor Operations                                                                                                 1
# Associate Wfm Manager (Bangkok Or Kuala Lumpur Based, Relocation Provided)                                                  1
# Associate, Channel/Partner Promotion Vision Care (Ismailia)                                                                 1
# Associate, Material Planning                                                                                                1
# Assurance - Merc - Resourcing Officer - Associate - Cairo, Egypt                                                            1
# Vas Subscription Manager                                                                                                    1
# Vca Consulting Director, Acquiring                                                                                          1
# Vca Snr Director, Nalp                                                                                                      1
# Vcs Sales Head - Nalp (Can Be Based In Lebanon Or Egypt)                                                                    1
# Vendor Manager (Recruiter) For Ai Related Services (Hybrid)                                                                 1
# Vendor Manager , Ohl , Retail                                                                                               1
# Vendor Reporting And Operations                                                                                             1
# Verification Consultant                                                                                                     1
# Verification Ip Product Engineer                                                                                            1
# Vice President, Customer Success                                                                                            1
# Vice President, Innovation                                                                                                  1
# Assistant Facilities Manager                                                                                                1
# Assistant Learning & Development Manager                                                                                    1
# Assistant Professor - Clinical Track: Infectious Diseases >>>                                                               1
# Assistant Professor Of Kinesiology For Coaching, Health, And Physical Education                                             1
# Associate - Internal Controls Finance & Treasury · Cairo                                                                    1
# Architect                                                                                                                   1
# Architect & Urban Designer ( To Be Based In Riyadh, Ksa)                                                                    1
# Architect Engineer                                                                                                          1
# Architect- Design Consulting Background ( To Be Based In Riyadh,Ksa)                                                        1
# Architecture Coordinator, Pds Projects                                                                                      1
# Architecture Designer                                                                                                       1
# Area Manager                                                                                                                1
# Armenian Remote Interpretation (Remote)                                                                                     1
# Asic Verification Engineer                                                                                                  1
# Assembly Manager                                                                                                            1
# Assistant Campaign Manager                                                                                                  1
# Assistant Comm & Interior Design Manager                                                                                    1
# Assistant Cost Consultant                                                                                                   1
# Assistant Cost Manager - Egypt                                                                                              1
# Valet Runner                                                                                                                1
# Value Added Services Engineer                                                                                               1
# Aom Project Manager                                                                                                         1
# Ap Accountant ( Odoo )                                                                                                      1
# Ap Accountant - French Speaker                                                                                              1
# Ap Manager                                                                                                                  1
# Ap Posting Associate                                                                                                        1
# Api Management Team Head                                                                                                    1
# Application Deployment & Release Specialist                                                                                 1
# Application Developer                                                                                                       1
# Application Management Consultant                                                                                           1
# Application Support Coordinator                                                                                             1
# Appointment Setter                                                                                                          1
# Appointment Setter (Fully Remote)                                                                                           1
# Ar Manager                                                                                                                  1
# Arabic English Interpreter                                                                                                  1
# Arabic English Interpretes (Remote) (Remote)                                                                                1
# Arabic/English Translator And Quality Assurance                                                                             1
# Agile Psychosocial Practitioner (App)                                                                                       1
# Agribusiness Specialist                                                                                                     1
# Agro Seeds Manager- Ismailia Farm                                                                                           1
# Agro Warehouse Officer                                                                                                      1
# Ai Delivery Sr Specialist                                                                                                   1
# Ai Engineering Lead                                                                                                         1
# Ai Product Manager                                                                                                          1
# Ai/Ml Team Lead                                                                                                             1
# Ain Shams Career Fair                                                                                                       1
# Air Freight Operations Executive                                                                                            1
# Air Logistics Sales Representative                                                                                          1
# Airport Representative                                                                                                      1
# Alternance Process Interfaces Outils Informatiques (H/F)                                                                    1
# Amazon Seo & Ppc Specialist                                                                                                 1
# Anti-Fraud Sr. Analyst                                                                                                      1
# Ao Bank Recon. Associate                                                                                                    1
# 3D Visualizer ( Interior & Architect )                                                                                      1
# Warehouses Manager                                                                                                          1
# Water Treatment Chemicals Senior Sales Engineer                                                                             1
# Wealth Management Relationship Manager                                                                                      1
# Wholesale Sales                                                                                                             1
# Wholesale Sales Representative                                                                                              1
# Wordpress Developer                                                                                                         1
# Yeast Consultant                                                                                                            1
# Youth Program Senior Specialist                                                                                             1
# Youtube Copyrights Specialist - Project-Based                                                                               1
# Youtube Seo Specialist - Project-Based                                                                                      1
# Zoho Business Development Associate                                                                                         1
# Zoho Developer                                                                                                              1
# Zoho Implementation Specialist                                                                                              1
# Zoho Support Specialist                                                                                                     1
# Advisory Operations Specialist                                                                                              1
# Sales Agent (Spanish Speaker)                                                                                               1
# Sales Assistant Analyst (Routing Engineering)                                                                               1
# Acquisition Lead (Incl. Digital Acquisition)                                                                                1
# Acquisition Manager (Incl. Digital Acquisition)                                                                             1
# Acquisition Specialist (Incl. Digital Acquisition)                                                                          1
# Activations Team Leader                                                                                                     1
# Ad Operations Manager                                                                                                       1
# Adjunct Faculty - Sociology/Anthropology (Fall 2025)                                                                        1
# Admin                                                                                                                       1
# Admin Coordinator                                                                                                           1
# Admin Support Analyst, Egypt 3Pl & Direct Imports                                                                           1
# Administration Supervisor                                                                                                   1
# Administrative Experience In The Field Of Contracting                                                                       1
# Administrative Supervisor                                                                                                   1
# Administrator (Facilities)                                                                                                  1
# Advisor                                                                                                                     1
# Name: count, dtype: int64

# %%
conn = sqlite3.connect('../data/database.db')
# df.to_sql('EGYPT', con=conn, if_exists='replace')
# conn.close()
